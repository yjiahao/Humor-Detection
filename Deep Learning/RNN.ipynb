# %% [markdown]
# # Introduction

# %% [markdown]
# Here are the steps we will take in this notebook to train our RNN

# %% [markdown]
# 1. Import Libraries
# 2. Prepare Dataset
# 3. Create RNN Model
# 4. hidden layer dimension is 100
# 5. number of hidden layer is 1
# 6. Instantiate Model
# 7. Instantiate Loss (Cross entropy loss)
# 8. Instantiate Optimizer (SGD Optimizer or Adam optimizer)
# 9. Traning the Model
# 10. Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torchtext
import torch.nn as nn
from torch.autograd import Variable
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
# Out:
# /usr/local/lib/python3.10/dist-packages/torchtext/data/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /usr/local/lib/python3.10/dist-packages/torchtext/vocab/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /usr/local/lib/python3.10/dist-packages/torchtext/utils.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)

# %% [markdown]
# # Reading data

# %%
train_df = pd.read_csv('ML_train.csv') # data/ML/ML_train.csv
test_df = pd.read_csv('ML_test.csv') # data/ML/ML_test.csv

# %%
seed = 42

np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# # Creation of validation set

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train_df['text'], train_df['humor'], test_size=0.1, random_state=42)

# %% [markdown]
# Conversion of labels into numpy arrays

# %%
# convert our train target values into a numpy array
train_targets_np = y_train.values
train_targets_np
# Out:
# array([False,  True, False, ..., False,  True,  True])

# %%
# convert validation target values into numpy array
valid_targets_np = y_valid.values
valid_targets_np
# Out:
# array([False,  True, False, ..., False,  True, False])

# %%
# convert test target values into a numpy array
test_targets_np = test_df['humor'].values
test_targets_np
# Out:
# array([ True,  True, False, ...,  True, False, False])

# %% [markdown]
# Conversion of features into numpy arrays

# %%
# convert the features column (text) into numpy arrays
train_features_numpy = X_train.values
train_features_numpy
# Out:
# array(['donald trump position get behind',
#        'die going kill could live without',
#        'man faced unimaginable suffering wrote definitive book happiness',
#        ..., 'satya nadella said woman asking raise',
#        'hey girl fitness well fitness cock mouth',
#        'neighbor vampire stabbed heart wooden stake died'], dtype=object)

# %%
# do the same for the validation set
valid_features_numpy = X_valid.values
valid_features_numpy
# Out:
# array(['heroic food truck coming rescue california fire victim',
#        'gay friend must businessmen keep talking partner',
#        'jada pinkett smith share relationship advice facebook', ...,
#        'happens mix world greatest drug booze',
#        'general patton thanksgiving gave tank',
#        'blink 182 album rereleased cassette tape'], dtype=object)

# %%
# do the same for the test set
test_features_numpy = test_df.loc[:, test_df.columns != 'humor'].values
test_features_numpy
#  = np.array([t[0] for t in test_features_numpy])
# test_features_numpy
# Out:
# array([['thought reddit joke today triangle rectangle fails'],
#        ['much pirate pay corn buck ear'],
#        ['hillary clinton sent book every gop candidateexcept one'],
#        ...,
#        ['best drug sex birth control'],
#        ['fit link tony hortons rule gym success first yoga class'],
#        ['positive prognosis climate negotiation']], dtype=object)

# %%
# checking that the data was split correctly
print(f"Train features length: {len(train_features_numpy)}")
print(f"Train targets length: {len(train_targets_np)}")
print(f"Validation features length: {len(valid_features_numpy)}")
print(f"Validation targets length: {len(valid_targets_np)}")
print(f"Test features length: {len(test_features_numpy)}")
print(f"Test targets length: {len(test_targets_np)}")
# Out:
# Train features length: 144000
# Train targets length: 144000
# Validation features length: 16000
# Validation targets length: 16000
# Test features length: 40000
# Test targets length: 40000

# %% [markdown]
# # Convert text into tokens, and numericalize the text

# %% [markdown]
# Tokenize the text using a tokenizer

# %%
tokenizer = get_tokenizer("basic_english")

def tokenize(sent, tokenizer, max_length):
    tokens = tokenizer(sent)[:max_length]
    length = len(tokens)
    return {"tokens": tokens, "length": length}

# %%
max_length = 100

X_train = [tokenize(x, tokenizer, max_length) for x in train_features_numpy]
X_train
# Out:
# [{'tokens': ['donald', 'trump', 'position', 'get', 'behind'], 'length': 5},
#  {'tokens': ['die', 'going', 'kill', 'could', 'live', 'without'], 'length': 6},
#  {'tokens': ['man',
#    'faced',
#    'unimaginable',
#    'suffering',
#    'wrote',
#    'definitive',
#    'book',
#    'happiness'],
#   'length': 8},
#  {'tokens': ['alex',
#    'poythress',
#    'always',
#    'score',
#    'point',
#    'prefers',
#    'amazing',
#    'gifs'],
#   'length': 8},
#  {'tokens': ['watch', 'kid', 'get', 'hilariously', 'honest', 'thankful'],
#   'length': 6},
#  {'tokens': ['message',
#    'kentucky',
#    'clerk',
#    'kim',
#    'davis',
#    'girl',
#    'take',
#    'romper'],
#   'length': 8},
#  {'tokens': ['hear', 'deaf', 'guy', 'could', 'sing', 'ya', 'well'],
#   'length': 7},
#  {'tokens': ['university',
#    'leader',
#    'showed',
#    'college',
#    'failure',
#    'sexual',
#    'assault',
#    'case'],
#   'length': 8},
#  {'tokens': ['computer', 'said', 'hello', 'think', 'dell'], 'length': 5},
#  {'tokens': ['call', 'fat', 'pirate', 'vast', 'matey'], 'length': 5},
#  {'tokens': ['30', 'sign', 'kid', 'turning', 'hipster'], 'length': 5},
#  {'tokens': ['asgardian', 'like', 'party', 'loki'], 'length': 4},
#  {'tokens': ['really', 'matter', 'second', 'baby', 'wear', 'handmedowns'],
#   'length': 6},
#  {'tokens': ['double', 'entendre', 'know', 'hell', 'saying', 'twice'],
#   'length': 6},
#  {'tokens': ['changed', 'iphones', 'name', 'titanic', 'syncing'], 'length': 5},
#  {'tokens': ['straight',
#    'outta',
#    'compton',
#    'named',
#    'best',
#    'film',
#    '2015',
#    'black',
#    'film',
#    'critic'],
#   'length': 10},
#  {'tokens': ['three',
#    'way',
#    'spread',
#    'news',
#    'telegram',
#    'television',
#    'tellawoman'],
#   'length': 7},
#  {'tokens': ['trailer',
#    'netflixs',
#    'discovery',
#    'jason',
#    'segel',
#    'rooney',
#    'mara',
#    'exploring',
#    'afterlife'],
#   'length': 9},
#  {'tokens': ['25th', 'anniversary', 'fall', 'berlin', 'wall'], 'length': 5},
#  {'tokens': ['devon',
#    'still',
#    'accepts',
#    'jimmy',
#    'v',
#    'perseverance',
#    'award',
#    'behalf',
#    'daughter',
#    'leah'],
#   'length': 10},
#  {'tokens': ['trouble', 'paradise', 'yous', 'ally', 'uae', 'crush', 'dissent'],
#   'length': 7},
#  {'tokens': ['rex',
#    'tillerson',
#    'sign',
#    'declaration',
#    'calling',
#    'climate',
#    'change',
#    'threat',
#    'arctic'],
#   'length': 9},
#  {'tokens': ['better', 'truer', 'southern', 'way', 'make', 'grit'],
#   'length': 6},
#  {'tokens': ['neyo',
#    'saturday',
#    'night',
#    'live',
#    'singer',
#    'performs',
#    'let',
#    'love',
#    'video'],
#   'length': 9},
#  {'tokens': ['hillary',
#    'clinton',
#    'challenged',
#    'defending',
#    'wall',
#    'street',
#    'donor',
#    'citing',
#    '911'],
#   'length': 9},
#  {'tokens': ['chamillionaire',
#    'responds',
#    'critic',
#    'get',
#    'helped',
#    'mexican',
#    'immigrant'],
#   'length': 7},
#  {'tokens': ['tell', 'head', 'doctor', 'one', 'dirtiest', 'knee'],
#   'length': 6},
#  {'tokens': ['michael',
#    'phelps',
#    'combined',
#    '19',
#    'gold',
#    'medal',
#    '4',
#    'duis'],
#   'length': 8},
#  {'tokens': ['best',
#    'way',
#    'get',
#    'man',
#    'remember',
#    'anniversary',
#    'get',
#    'married',
#    'birthday'],
#   'length': 9},
#  {'tokens': ['girl',
#    'facebook',
#    'call',
#    'walk',
#    'shame',
#    'girl',
#    'twitter',
#    'call',
#    'strut',
#    'satisfaction'],
#   'length': 10},
#  {'tokens': ['broken', 'window', 'go', 'doctor', 'pane'], 'length': 5},
#  {'tokens': ['watch',
#    'drag',
#    'queen',
#    'interview',
#    'trump',
#    'supporter',
#    'inauguration'],
#   'length': 7},
#  {'tokens': ['trump',
#    'hint',
#    'obamacare',
#    'replacement',
#    'would',
#    'look',
#    'nothing',
#    'like',
#    'republican',
#    'mind'],
#   'length': 10},
#  {'tokens': ['know',
#    'sister',
#    'period',
#    'dad',
#    'dick',
#    'taste',
#    'like',
#    'blood'],
#   'length': 8},
#  {'tokens': ['shut', 'fk', 'beauty', 'death', 'control'], 'length': 5},
#  {'tokens': ['difference',
#    'pick',
#    'pocket',
#    'peeping',
#    'tom',
#    'pick',
#    'pocket',
#    'snatch',
#    'watch'],
#   'length': 9},
#  {'tokens': ['kid',
#    'asking',
#    'fed',
#    'cared',
#    'stuff',
#    'parenting',
#    'thing',
#    'bullshit'],
#   'length': 8},
#  {'tokens': ['2',
#    'republican',
#    'senator',
#    'revoke',
#    'support',
#    'garland',
#    'hearing'],
#   'length': 7},
#  {'tokens': ['artist',
#    'honey',
#    'bee',
#    'project',
#    'come',
#    'dire',
#    'environmental',
#    'warning'],
#   'length': 8},
#  {'tokens': ['tried', 'little', 'rabbit', 'peep', 'tasted', 'like', 'chicken'],
#   'length': 7},
#  {'tokens': ['redneck', 'find', 'sister', 'wood', 'attractive'], 'length': 5},
#  {'tokens': ['saddest', 'olympic', 'sport', 'watch', 'water', 'polio'],
#   'length': 6},
#  {'tokens': ['successful', 'right', 'way'], 'length': 3},
#  {'tokens': ['giving', 'present', 'christmas', 'photo'], 'length': 4},
#  {'tokens': ['spot', 'blind', 'man', 'nudist', 'beach', 'hard'], 'length': 6},
#  {'tokens': ['another',
#    'trumpian',
#    'senate',
#    'contender',
#    'link',
#    'obama',
#    'orlando',
#    'shooting'],
#   'length': 8},
#  {'tokens': ['even',
#    'white',
#    'house',
#    'asian',
#    'labeled',
#    'model',
#    'minority'],
#   'length': 7},
#  {'tokens': ['difference', 'jelly', 'jam', 'jelly', 'dick', 'throat'],
#   'length': 6},
#  {'tokens': ['reverse',
#    'mortgage',
#    'boomer',
#    'increasingly',
#    'rely',
#    'risky',
#    'loan'],
#   'length': 7},
#  {'tokens': ['5',
#    'living',
#    'former',
#    'yous',
#    'president',
#    'attend',
#    'hurricane',
#    'relief',
#    'concert'],
#   'length': 9},
#  {'tokens': ['iraqi',
#    'afghan',
#    'helped',
#    'yous',
#    'among',
#    'first',
#    'detained',
#    'trump',
#    'ban'],
#   'length': 9},
#  {'tokens': ['gop',
#    'debate',
#    'focus',
#    'economic',
#    'issue',
#    'fox',
#    'business',
#    'pledge'],
#   'length': 8},
#  {'tokens': ['south',
#    'carolina',
#    'minor',
#    'league',
#    'hockey',
#    'team',
#    'wear',
#    'charleston',
#    'strong',
#    'jersey'],
#   'length': 10},
#  {'tokens': ['dispatch', 'best', 'buy', 'black', 'friday'], 'length': 5},
#  {'tokens': ['ted',
#    'cruz',
#    'donald',
#    'trump',
#    'oppose',
#    'immigration',
#    'reform',
#    'could',
#    'helping',
#    'anyway'],
#   'length': 10},
#  {'tokens': ['kelo',
#    'turn',
#    '10',
#    'meet',
#    'new',
#    'victim',
#    'eminent',
#    'domain'],
#   'length': 8},
#  {'tokens': ['care', 'female', 'presidential', 'nominee', 'neither'],
#   'length': 5},
#  {'tokens': ['protect',
#    'car',
#    'door',
#    'hitting',
#    'garage',
#    'wall',
#    'using',
#    'pool',
#    'noodle',
#    'photo'],
#   'length': 10},
#  {'tokens': ['rumi',
#    'vedic',
#    'wisdom',
#    'happy',
#    'day',
#    'converge',
#    'emad',
#    'asfourys',
#    'duality'],
#   'length': 9},
#  {'tokens': ['top', 'home', 'exchange', 'tip', 'founder', 'homeexchangecom'],
#   'length': 6},
#  {'tokens': ['difference',
#    'feminist',
#    'sumo',
#    'wrestler',
#    'sumo',
#    'wrestler',
#    'shave',
#    'leg'],
#   'length': 8},
#  {'tokens': ['50',
#    'indian',
#    'road',
#    'filled',
#    'hole',
#    'rest',
#    'filled',
#    'asshole'],
#   'length': 8},
#  {'tokens': ['officer',
#    'slam',
#    'threw',
#    'teen',
#    'desk',
#    'cellphone',
#    'lawyer',
#    'say'],
#   'length': 8},
#  {'tokens': ['oxytocin',
#    'could',
#    'increase',
#    'anxiety',
#    'fear',
#    'response',
#    'future',
#    'stress'],
#   'length': 8},
#  {'tokens': ['jennifer',
#    'anistons',
#    'yoga',
#    'teacher',
#    'mandy',
#    'ingber',
#    'star',
#    'stay',
#    'cool',
#    'calm',
#    'collected'],
#   'length': 11},
#  {'tokens': ['blood', 'type', 'people', 'taiwan', 'capital', 'city', 'taipei'],
#   'length': 7},
#  {'tokens': ['scoundrel',
#    'stoner',
#    'elvis',
#    'year',
#    'life',
#    'michael',
#    'shannon'],
#   'length': 7},
#  {'tokens': ['warm',
#    'bone',
#    'ambient',
#    'heat',
#    'latest',
#    'merrick',
#    'garland',
#    'hot',
#    'take'],
#   'length': 9},
#  {'tokens': ['daughter',
#    'claim',
#    'mom',
#    'call',
#    '911',
#    'lonely',
#    'hear',
#    'call'],
#   'length': 8},
#  {'tokens': ['horsemeat',
#    'beef',
#    'alternative',
#    'french',
#    'eater',
#    'say',
#    'tastier',
#    'healthier'],
#   'length': 8},
#  {'tokens': ['large',
#    'grey',
#    'sings',
#    'great',
#    'jazz',
#    'song',
#    'elephant',
#    'gerald'],
#   'length': 8},
#  {'tokens': ['even', 'siri', 'know', 'sad', 'cleveland', 'brown'],
#   'length': 6},
#  {'tokens': ['remembering',
#    'new',
#    'zealand',
#    'rena',
#    'oil',
#    'spill',
#    '1',
#    'year',
#    'later'],
#   'length': 9},
#  {'tokens': ['paranoid', 'narcissist', 'afraid', 'one', 'get'], 'length': 5},
#  {'tokens': ['diagnosed', 'colorblindness', 'surprised', 'came', 'green'],
#   'length': 5},
#  {'tokens': ['huffpost',
#    'tastemakers',
#    'alain',
#    'allegretti',
#    'prep',
#    'restaurant',
#    'week'],
#   'length': 7},
#  {'tokens': ['herb',
#    'garden',
#    'essential',
#    'grow',
#    'beautiful',
#    'tasty',
#    'thyme'],
#   'length': 7},
#  {'tokens': ['difference',
#    'redwood',
#    'dead',
#    'baby',
#    'redwood',
#    'fit',
#    'wood',
#    'chipper'],
#   'length': 8},
#  {'tokens': ['river', 'negation', 'called', 'nile'], 'length': 4},
#  {'tokens': ['conan', 'glorious', 'super', 'suit', 'made', 'comiccon'],
#   'length': 6},
#  {'tokens': ['caught', 'mosquito', 'hand', 'sucked'], 'length': 4},
#  {'tokens': ['pride',
#    'summer',
#    '8',
#    'lgbt',
#    'event',
#    'still',
#    'attend',
#    'year'],
#   'length': 8},
#  {'tokens': ['found',
#    'dating',
#    'commie',
#    'guess',
#    'noticed',
#    'red',
#    'flag',
#    'earlier'],
#   'length': 8},
#  {'tokens': ['jam', 'slam', 'dunk', 'contest', 'even', 'sicker', '360'],
#   'length': 7},
#  {'tokens': ['46',
#    'best',
#    'vine',
#    'week',
#    'one',
#    'video',
#    'august',
#    '17',
#    'august',
#    '25',
#    '2013'],
#   'length': 11},
#  {'tokens': ['call', 'wizard', 'good', 'outlook', 'life', 'optimystic'],
#   'length': 6},
#  {'tokens': ['dig', '16', 'designer', 'decor', 'find', 'spruce', 'space'],
#   'length': 7},
#  {'tokens': ['greece',
#    'creditor',
#    'push',
#    'breakthrough',
#    'bailout',
#    'talk',
#    'time',
#    'run'],
#   'length': 8},
#  {'tokens': ['lawyer', 'sleep', 'rest', 'case'], 'length': 4},
#  {'tokens': ['many', 'state', 'longawaited', 'raise', 'lowpaid', 'worker'],
#   'length': 6},
#  {'tokens': ['joke', 'guy', 'cooking', 'gay', 'long', 'mitt', 'touch'],
#   'length': 7},
#  {'tokens': ['taylor', 'swift', 'highestpaid', 'woman', 'music', '2016'],
#   'length': 6},
#  {'tokens': ['survey', 'shown', '67', 'dwarf', 'happy'], 'length': 5},
#  {'tokens': ['hi', 'electron', 'home', 'tonight', 'probably'], 'length': 5},
#  {'tokens': ['yo', 'mama', 'ugly', 'turned', 'medusa', 'stone'], 'length': 6},
#  {'tokens': ['tried',
#    'teach',
#    'grandma',
#    'eat',
#    'noodle',
#    'chopstick',
#    'accidentally',
#    'made',
#    'sweater'],
#   'length': 9},
#  {'tokens': ['call', '5', 'black', 'people', 'sex', 'threesome'], 'length': 6},
#  {'tokens': ['bachelor',
#    'season',
#    '21',
#    'episode',
#    '7',
#    'make',
#    'friend',
#    'podcast'],
#   'length': 8},
#  {'tokens': ['killer',
#    'mike',
#    'delivers',
#    'powerful',
#    'endorsement',
#    'bernie',
#    'sander'],
#   'length': 7},
#  {'tokens': ['dna', 'man', 'poopy', 'short', 'lead', 'arrest'], 'length': 6},
#  {'tokens': ['sorry',
#    'adavance',
#    'part',
#    'vegetable',
#    'cannot',
#    'eat',
#    'wheelchair'],
#   'length': 7},
#  {'tokens': ['stefano', 'pilati', 'easy', 'find', 'elegant', 'woman'],
#   'length': 6},
#  {'tokens': ['fall', 'always', 'sincerely', 'floor'], 'length': 4},
#  {'tokens': ['call', 'vegan', 'wizard', 'soyceror'], 'length': 4},
#  {'tokens': ['nuri',
#    'bilge',
#    'ceylans',
#    'winter',
#    'sleep',
#    'win',
#    'palme',
#    'dor',
#    'cannes',
#    'masterpiece'],
#   'length': 10},
#  {'tokens': ['team',
#    'trump',
#    'bizarre',
#    'mission',
#    'convince',
#    'value',
#    'woman'],
#   'length': 7},
#  {'tokens': ['5', 'annoying', 'trend', 'want', 'go', 'away'], 'length': 6},
#  {'tokens': ['longest', 'joke', 'world', 'dick', 'see', 'coming'],
#   'length': 6},
#  {'tokens': ['hype',
#    'major',
#    'release',
#    'star',
#    'war',
#    'vii',
#    'hope',
#    'diminished',
#    'quality'],
#   'length': 9},
#  {'tokens': ['affluenza',
#    'teen',
#    'ethan',
#    'couch',
#    'deported',
#    'mexico',
#    'return',
#    'texas'],
#   'length': 8},
#  {'tokens': ['many',
#    'ear',
#    'captain',
#    'kirk',
#    'three',
#    'right',
#    'ear',
#    'left',
#    'ear',
#    'final',
#    'frontier'],
#   'length': 11},
#  {'tokens': ['french',
#    'pm',
#    'europe',
#    'risk',
#    'collapse',
#    'france',
#    'germany',
#    'must',
#    'lead'],
#   'length': 9},
#  {'tokens': ['pig', 'run', 'medicine', 'hate', 'getting', 'cured'],
#   'length': 6},
#  {'tokens': ['say', 'say', 'rectum', 'damn', 'near', 'killed'], 'length': 6},
#  {'tokens': ['like',
#    'reddit',
#    'joke',
#    'like',
#    'like',
#    'coffee',
#    'dark',
#    'tasteless'],
#   'length': 8},
#  {'tokens': ['normal',
#    'doctor',
#    'see',
#    'penis',
#    'yell',
#    'magnificent',
#    'right'],
#   'length': 7},
#  {'tokens': ['body',
#    'recovered',
#    'scene',
#    'new',
#    'york',
#    'city',
#    'building',
#    'explosion'],
#   'length': 8},
#  {'tokens': ['10', 'nfl', 'player', 'closing', 'big', 'new', 'contract'],
#   'length': 7},
#  {'tokens': ['ever',
#    'tasted',
#    'traditional',
#    'ethiopian',
#    'food',
#    'neither',
#    'show'],
#   'length': 7},
#  {'tokens': ['top',
#    '10',
#    'scholarship',
#    'african',
#    'american',
#    'student',
#    'deadline',
#    'january',
#    '2014'],
#   'length': 9},
#  {'tokens': ['could', 'travel', 'space', 'soon', '2018'], 'length': 5},
#  {'tokens': ['atheist', 'afraid', 'exponent', 'believe', 'higher', 'power'],
#   'length': 6},
#  {'tokens': ['todd',
#    'colin',
#    'father',
#    'son',
#    'walking',
#    'across',
#    'america',
#    'lose',
#    'weight'],
#   'length': 9},
#  {'tokens': ['third', 'ear', 'earring', 'etsy', 'make', 'doubletake', 'photo'],
#   'length': 7},
#  {'tokens': ['gay',
#    'apps',
#    'must',
#    'act',
#    'stop',
#    'entrapment',
#    'around',
#    'world'],
#   'length': 8},
#  {'tokens': ['last',
#    'night',
#    'dreamt',
#    'ate',
#    'giant',
#    'marshmallow',
#    'woke',
#    'pillow',
#    'gone'],
#   'length': 9},
#  {'tokens': ['wondering', 'night', 'long', 'dawned', 'upon'], 'length': 5},
#  {'tokens': ['hydraulic',
#    'press',
#    'crusher',
#    'celebrates',
#    'youtube',
#    'award',
#    'way',
#    'know'],
#   'length': 8},
#  {'tokens': ['call', 'bear', 'without', 'teeth', 'gummi', 'bear'],
#   'length': 6},
#  {'tokens': ['double',
#    'limb',
#    'transplant',
#    'expensive',
#    'cost',
#    'arm',
#    'leg'],
#   'length': 7},
#  {'tokens': ['politician', 'hate', 'love', 'america'], 'length': 4},
#  {'tokens': ['dear',
#    'parent',
#    'unattended',
#    'child',
#    'given',
#    '4',
#    'red',
#    'bull',
#    'kazoo'],
#   'length': 9},
#  {'tokens': ['daily', 'pot', 'smoking', 'college', 'campus', '35year', 'high'],
#   'length': 7},
#  {'tokens': ['state',
#    'life',
#    'expectancy',
#    'report',
#    'detail',
#    'gain',
#    'loss',
#    'life',
#    'expectancy',
#    'around',
#    'country'],
#   'length': 11},
#  {'tokens': ['donald',
#    'trump',
#    'seems',
#    'time',
#    'everything',
#    'question',
#    'business',
#    'conflict'],
#   'length': 8},
#  {'tokens': ['journalist',
#    'unite',
#    'white',
#    'house',
#    'attack',
#    'medium',
#    'call',
#    'collective',
#    'defense'],
#   'length': 9},
#  {'tokens': ['picture', 'fox', 'wrong', 'smaller'], 'length': 4},
#  {'tokens': ['webmd',
#    'auto',
#    'dialed',
#    'ambulance',
#    'entered',
#    'chicken',
#    'nugget',
#    'intake'],
#   'length': 8},
#  {'tokens': ['gandalfs', 'favorite', 'band', 'flock', 'smeagols'],
#   'length': 5},
#  {'tokens': ['new',
#    'year',
#    'resolution',
#    'yous',
#    'policy',
#    'towards',
#    'latin',
#    'america',
#    'check',
#    'list'],
#   'length': 10},
#  {'tokens': ['seeking', 'time', 'gone', 'rocky', 'mountain', 'high'],
#   'length': 6},
#  {'tokens': ['guess', 'election', 'always', 'dumb'], 'length': 4},
#  {'tokens': ['6', 'eye', 'cannot', 'see', '3', 'blind', 'mouse'], 'length': 7},
#  {'tokens': ['phone', 'invented', 'dick', 'pic', 'called', 'junk', 'mail'],
#   'length': 7},
#  {'tokens': ['government', 'employee', 'constipated', 'shit'], 'length': 4},
#  {'tokens': ['shout', 'people', 'know', 'opposite'], 'length': 4},
#  {'tokens': ['paul',
#    'mccartney',
#    'actually',
#    'denied',
#    'entrance',
#    'tygas',
#    'grammys',
#    'afterparty'],
#   'length': 8},
#  {'tokens': ['carly',
#    'rae',
#    'jepsen',
#    'owl',
#    'city',
#    'see',
#    'royalty',
#    'good',
#    'time',
#    'due',
#    'lawsuit'],
#   'length': 11},
#  {'tokens': ['bumped',
#    'old',
#    'english',
#    'teacher',
#    'said',
#    'new',
#    'said',
#    'adjective'],
#   'length': 8},
#  {'tokens': ['call', 'vegetable', 'escaped', 'prison', 'escapea'],
#   'length': 5},
#  {'tokens': ['say', 'happy', 'know', 'drop', 'pant'], 'length': 5},
#  {'tokens': ['call', 'cookbook', 'dead', 'necrinomnomnomicon'], 'length': 4},
#  {'tokens': ['swear',
#    'word',
#    'faggot',
#    'shit',
#    'fuck',
#    'dick',
#    'nigger',
#    'slut',
#    'as',
#    'pussy',
#    'cunt',
#    'damn',
#    'whitey'],
#   'length': 13},
#  {'tokens': ['bloomberg',
#    'businessweek',
#    'cover',
#    'take',
#    'aim',
#    'donald',
#    'trump',
#    'destabilizing',
#    'executive',
#    'order'],
#   'length': 10},
#  {'tokens': ['session', 'health', 'care', 'fall', 'trump'], 'length': 5},
#  {'tokens': ['british',
#    'pundit',
#    'ate',
#    'book',
#    'tv',
#    'year',
#    'weird',
#    'enough'],
#   'length': 8},
#  {'tokens': ['racist',
#    'black',
#    'white',
#    'unemployed',
#    'kidding',
#    'white',
#    'part'],
#   'length': 7},
#  {'tokens': ['interview',
#    'ian',
#    'mac',
#    'mclagan',
#    'legendary',
#    'small',
#    'face',
#    'new',
#    'amazing',
#    'box',
#    'set'],
#   'length': 11},
#  {'tokens': ['answering', 'question', 'day'], 'length': 3},
#  {'tokens': ['tomato', 'blushing', 'answer', 'saw', 'salad', 'dressing'],
#   'length': 6},
#  {'tokens': ['calle', '13', 'explores', 'power', 'kiss'], 'length': 5},
#  {'tokens': ['ok',
#    'imagine',
#    'fleshlight',
#    'full',
#    'food',
#    'hot',
#    'pocket',
#    'sale',
#    'pitch'],
#   'length': 9},
#  {'tokens': ['merry',
#    'christmas',
#    'mr',
#    'presidentelect',
#    '10',
#    'place',
#    'nuke',
#    'starting',
#    'january',
#    '20'],
#   'length': 10},
#  {'tokens': ['travel', 'lying', 'travel', 'might', 'key', 'dating', 'success'],
#   'length': 7},
#  {'tokens': ['get', 'cross', 'beatle', 'australian', 'dog', 'dingo', 'starr'],
#   'length': 7},
#  {'tokens': ['dinosaur', 'wear', 'glass', 'make', 'sure', 'step', 'dinosaur'],
#   'length': 7},
#  {'tokens': ['lizzie', 'borden', 'couple', 'really', 'good', 'lifehacks'],
#   'length': 6},
#  {'tokens': ['gilded',
#    'glamour',
#    'galore',
#    'whimsical',
#    'weekend',
#    'newport',
#    'rhode',
#    'island'],
#   'length': 8},
#  {'tokens': ['michael', 'jordan', 'suggests', 'kobe', 'try', 'enjoy', 'life'],
#   'length': 7},
#  {'tokens': ['got', '306', 'fewer', 'rep', 'talayna'], 'length': 5},
#  {'tokens': ['dying', 'get', 'one', 'baby', 'smoke', 'cute'], 'length': 6},
#  {'tokens': ['2', 'guy', 'walk', 'bar', 'third', 'guy', 'duck'], 'length': 7},
#  {'tokens': ['climate',
#    'agreement',
#    'make',
#    'history',
#    'real',
#    'work',
#    'begin'],
#   'length': 7},
#  {'tokens': ['get',
#    'cross',
#    'automobile',
#    'household',
#    'animal',
#    'upset',
#    'child'],
#   'length': 7},
#  {'tokens': ['usually', 'find', 'four', 'catholic', 'fifth'], 'length': 5},
#  {'tokens': ['anne',
#    'hathaway',
#    'emma',
#    'watson',
#    'mia',
#    'farrow',
#    'star',
#    'short',
#    'hair',
#    'photo'],
#   'length': 10},
#  {'tokens': ['two',
#    'fish',
#    'tank',
#    'one',
#    'turned',
#    'back',
#    'said',
#    'anotherhow',
#    'drive',
#    'thing'],
#   'length': 10},
#  {'tokens': ['time', 'sean', 'connery', 'go', 'wimbledon', 'tenish'],
#   'length': 6},
#  {'tokens': ['much', 'college', 'football', 'player', 'making'], 'length': 5},
#  {'tokens': ['fruit', 'business', 'went', 'liquidation', 'sell', 'smoothy'],
#   'length': 6},
#  {'tokens': ['soldier',
#    'surprise',
#    'dance',
#    'teacher',
#    'girlfriend',
#    'onstage',
#    'proposal',
#    'video'],
#   'length': 8},
#  {'tokens': ['movie', 'attendance', 'hit', '19year', 'low', '2014'],
#   'length': 6},
#  {'tokens': ['beginning',
#    'god',
#    'created',
#    'heaven',
#    'earth',
#    'rest',
#    'made',
#    'china'],
#   'length': 8},
#  {'tokens': ['woman',
#    'walk',
#    'bar',
#    'order',
#    'double',
#    'entendre',
#    'bartender',
#    'give'],
#   'length': 8},
#  {'tokens': ['manchester',
#    'united',
#    'dumped',
#    'fa',
#    'cup',
#    'swansea',
#    'city',
#    'wilfried',
#    'bony',
#    'videophotos'],
#   'length': 10},
#  {'tokens': ['exceo',
#    'rentboycom',
#    'get',
#    'six',
#    'month',
#    'prison',
#    'promoting',
#    'prostitution'],
#   'length': 8},
#  {'tokens': ['face', 'let', 'u', 'talk', 'talking', 'sex'], 'length': 6},
#  {'tokens': ['mime', 'always', 'lose', 'argument', 'say', 'anything'],
#   'length': 6},
#  {'tokens': ['mexican',
#    'go',
#    'bow',
#    'hunting',
#    'native',
#    'american',
#    'habanero'],
#   'length': 7},
#  {'tokens': ['life',
#    'one',
#    'long',
#    'earthquake',
#    'tiny',
#    'dog',
#    'always',
#    'shaking'],
#   'length': 8},
#  {'tokens': ['person',
#    'strives',
#    'ensure',
#    'safety',
#    'horse',
#    'ralph',
#    'neighder'],
#   'length': 7},
#  {'tokens': ['sean',
#    'spicer',
#    'asked',
#    'penny',
#    'replace',
#    'trump',
#    'seth',
#    'meyers',
#    'spoof'],
#   'length': 9},
#  {'tokens': ['kid',
#    'start',
#    'talking',
#    'back',
#    'realize',
#    'dog',
#    'would',
#    'better',
#    'option'],
#   'length': 9},
#  {'tokens': ['trump',
#    'team',
#    'denies',
#    'report',
#    'national',
#    'guard',
#    'admits',
#    'based',
#    'real',
#    'document'],
#   'length': 10},
#  {'tokens': ['invited', 'second', 'bar', 'mitzvah', 'become', 'child'],
#   'length': 6},
#  {'tokens': ['rancho',
#    'pescadero',
#    'antidote',
#    'cabo',
#    'road',
#    'todos',
#    'santos'],
#   'length': 7},
#  {'tokens': ['john',
#    'kasich',
#    'would',
#    'signed',
#    'north',
#    'carolina',
#    'antilgbt',
#    'law'],
#   'length': 8},
#  {'tokens': ['said', 'run', 'fun', 'know', 'internet'], 'length': 5},
#  {'tokens': ['buy',
#    'soap',
#    'rope',
#    'cashier',
#    'paper',
#    'plastic',
#    'neither',
#    'wear',
#    'thanks'],
#   'length': 9},
#  {'tokens': ['every',
#    'ceo',
#    'america',
#    'encouraging',
#    'meditation',
#    'work',
#    'place'],
#   'length': 7},
#  {'tokens': ['baby',
#    'seal',
#    'walk',
#    'bar',
#    'wait',
#    'baby',
#    'seal',
#    'walk',
#    'club'],
#   'length': 9},
#  {'tokens': ['20', 'thing', 'stop', 'giving', 'sht', '2016'], 'length': 6},
#  {'tokens': ['11', 'way', 'eating', 'food', 'wrong', 'video'], 'length': 6},
#  {'tokens': ['la',
#    'vega',
#    'sand',
#    'investigation',
#    'corruption',
#    'admits',
#    'violation',
#    'likely'],
#   'length': 8},
#  {'tokens': ['miami',
#    'poop',
#    'map',
#    'us',
#    'emojis',
#    'make',
#    'case',
#    'homeless',
#    'need',
#    'bathroom'],
#   'length': 10},
#  {'tokens': ['watched', 'gay', 'fish', 'porn', 'day', 'pretty', 'homoaquatic'],
#   'length': 7},
#  {'tokens': ['supreme',
#    'court',
#    'could',
#    'throw',
#    'lifeline',
#    'debtswamped',
#    'puerto',
#    'rico'],
#   'length': 8},
#  {'tokens': ['midget', 'fired', 'job', 'came', 'short', 'register'],
#   'length': 6},
#  {'tokens': ['trump',
#    'describes',
#    'paris',
#    'terror',
#    'attack',
#    'boom',
#    'boom',
#    'boom'],
#   'length': 8},
#  {'tokens': ['difference', 'wife', 'job', 'job', 'still', 'suck'],
#   'length': 6},
#  {'tokens': ['realized',
#    'one',
#    'meal',
#    'today',
#    'one',
#    'thirteenhour',
#    'meal'],
#   'length': 7},
#  {'tokens': ['rude',
#    'people',
#    'ask',
#    'day',
#    'like',
#    'growing',
#    'hair',
#    'enough'],
#   'length': 8},
#  {'tokens': ['say', 'jewish', 'new', 'zealander', 'hee', 'brew'], 'length': 6},
#  {'tokens': ['volkswagen',
#    'emission',
#    'scandal',
#    'could',
#    'cause',
#    '1200',
#    'premature',
#    'death'],
#   'length': 8},
#  {'tokens': ['hey', 'get', 'haircut', 'today', 'got', 'cut'], 'length': 6},
#  {'tokens': ['middle',
#    'eastern',
#    'airline',
#    'respond',
#    'united',
#    'incident',
#    'tonedeaf',
#    'tweet'],
#   'length': 8},
#  {'tokens': ['john',
#    'conyers',
#    'iii',
#    'son',
#    'lawmaker',
#    'arrested',
#    'february',
#    'girlfriend',
#    'called',
#    '911'],
#   'length': 10},
#  {'tokens': ['common', 'disease', 'lettuce', 'icebergers'], 'length': 4},
#  {'tokens': ['guy', 'ran', 'bar', 'hospitalized'], 'length': 4},
#  {'tokens': ['top', '5', 'summer', 'activity', 'new', 'england', 'photo'],
#   'length': 7},
#  {'tokens': ['21',
#    'food',
#    'thing',
#    'san',
#    'franciscan',
#    'would',
#    'understand'],
#   'length': 7},
#  {'tokens': ['nyt',
#    'oped',
#    'militates',
#    'higher',
#    'oil',
#    'price',
#    'fewer',
#    'american',
#    'job'],
#   'length': 9},
#  {'tokens': ['straight',
#    'outta',
#    'compton',
#    'becomes',
#    'highestgrossing',
#    'movie',
#    'africanamerican',
#    'director'],
#   'length': 8},
#  {'tokens': ['13', 'food', 'saturated', 'fat', 'cheeseburger'], 'length': 5},
#  {'tokens': ['physically',
#    'possible',
#    'sad',
#    'rollerskates',
#    'think',
#    'cat',
#    'dramatic'],
#   'length': 7},
#  {'tokens': ['bad', 'inflight', 'announcement', 'mock', 'horror', 'flying'],
#   'length': 6},
#  {'tokens': ['life',
#    'earth',
#    'expensive',
#    'include',
#    'annual',
#    'free',
#    'trip',
#    'around',
#    'sun'],
#   'length': 9},
#  {'tokens': ['hear', 'islam', 'religion', 'peace', 'piece', 'piece'],
#   'length': 6},
#  {'tokens': ['cannot', 'donald', 'trump', 'lannister', 'never', 'pay', 'debt'],
#   'length': 7},
#  {'tokens': ['canadian', 'court', 'plead', 'sorry', 'sorry'], 'length': 5},
#  {'tokens': ['going', 'post', 'original', 'joke', 'rjokes'], 'length': 5},
#  {'tokens': ['going',
#    'cold',
#    'day',
#    'today',
#    'motown',
#    'three',
#    'degree',
#    'four',
#    'top'],
#   'length': 9},
#  {'tokens': ['lost', 'two', 'thing', 'today', 'virginity', 'job', 'morgue'],
#   'length': 7},
#  {'tokens': ['twitter',
#    'cannot',
#    'believe',
#    'rihanna',
#    'invented',
#    'punk',
#    'latest',
#    'photo',
#    'shoot'],
#   'length': 9},
#  {'tokens': ['vet', 'rock', 'puppy', 'like', 'baby', 'calm', 'surgery'],
#   'length': 7},
#  {'tokens': ['snow', 'security', 'blanket', 'year'], 'length': 4},
#  {'tokens': ['arizona',
#    'sheriff',
#    'joe',
#    'arpaio',
#    'build',
#    'border',
#    'wall',
#    'keep',
#    'terrorist'],
#   'length': 9},
#  {'tokens': ['kikkoman',
#    'soy',
#    'sauce',
#    'move',
#    'production',
#    'china',
#    'outsauced'],
#   'length': 7},
#  {'tokens': ['camel', 'horse', 'made', 'committee'], 'length': 4},
#  {'tokens': ['happy',
#    'international',
#    'childfree',
#    'day',
#    'announcing',
#    '2015',
#    'childfree',
#    'woman',
#    'man',
#    'year'],
#   'length': 10},
#  {'tokens': ['girlfriend',
#    'like',
#    'temperature',
#    'molecule',
#    'exist',
#    'definition'],
#   'length': 6},
#  {'tokens': ['check', 'doggos', 'enjoying', 'bomb', 'cyclone'], 'length': 5},
#  {'tokens': ['20', 'way', 'talk', 'teenage', 'daughter', 'fix', 'thing'],
#   'length': 7},
#  {'tokens': ['germany', 'lose', 'ww2', 'three', 'reich'], 'length': 5},
#  {'tokens': ['really',
#    'hard',
#    'balance',
#    'work',
#    'family',
#    'caring',
#    'anything'],
#   'length': 7},
#  {'tokens': ['federal',
#    'student',
#    'aid',
#    'office',
#    'call',
#    'failure',
#    'success',
#    'hand',
#    'big',
#    'bonus'],
#   'length': 10},
#  {'tokens': ['study', 'find', 'kill', 'give', 'mother', 'call', 'god', 'sake'],
#   'length': 8},
#  {'tokens': ['order', 'always', 'win', 'rock', 'paper', 'scissors', 'shoot'],
#   'length': 7},
#  {'tokens': ['fight', 'cold', 'kid', 'wait', 'move'], 'length': 5},
#  {'tokens': ['call',
#    'tardy',
#    'count',
#    'school',
#    'water',
#    'bear',
#    'tardigrade'],
#   'length': 7},
#  {'tokens': ['never', 'play', 'poker', 'piece', 'paper', 'bound', 'fold'],
#   'length': 7},
#  {'tokens': ['charlottesville', 'returning', 'normal', 'scare'], 'length': 4},
#  {'tokens': ['outsider',
#    'officially',
#    'squeezed',
#    'way',
#    'inside',
#    'art',
#    'world'],
#   'length': 7},
#  {'tokens': ['exda',
#    'expected',
#    'key',
#    'defense',
#    'witness',
#    'cosby',
#    'hearing'],
#   'length': 7},
#  {'tokens': ['republican',
#    'convicted',
#    'election',
#    'fraud',
#    'vip',
#    'access',
#    'trump',
#    'michigan',
#    'rally'],
#   'length': 9},
#  {'tokens': ['holiday',
#    'craft',
#    'idea',
#    'make',
#    'painted',
#    'metallic',
#    'golden',
#    'acorn'],
#   'length': 8},
#  {'tokens': ['meet', 'new', 'mom', 'old', 'mom'], 'length': 5},
#  {'tokens': ['reality', 'show', 'little', 'engine', 'called', 'think'],
#   'length': 6},
#  {'tokens': ['cemetery',
#    'dude',
#    'say',
#    'buried',
#    'wrong',
#    'guy',
#    'made',
#    'grave',
#    'mistake'],
#   'length': 9},
#  {'tokens': ['zombie',
#    'say',
#    'walked',
#    'wrong',
#    'tomb',
#    'made',
#    'grave',
#    'mistake'],
#   'length': 8},
#  {'tokens': ['north',
#    'korea',
#    'missile',
#    'launch',
#    'leave',
#    'short',
#    'reaction',
#    'window'],
#   'length': 8},
#  {'tokens': ['best', 'thing', 'sex', 'twentysix', 'year', 'old', '20'],
#   'length': 7},
#  {'tokens': ['amy', 'dixon', 'bakes', 'best', 'baker', 'table'], 'length': 6},
#  {'tokens': ['cinnamon',
#    'roll',
#    'sticky',
#    'bun',
#    'recipe',
#    'make',
#    'morning',
#    'sweeter'],
#   'length': 8},
#  {'tokens': ['organizer',
#    'release',
#    'qualifying',
#    'criterion',
#    'november',
#    'gop',
#    'debate'],
#   'length': 7},
#  {'tokens': ['authentic', 'european', 'experience', 'kid', 'cest', 'possible'],
#   'length': 6},
#  {'tokens': ['oh',
#    'god',
#    'genie',
#    'genie',
#    'please',
#    'prefer',
#    'magicamerican'],
#   'length': 7},
#  {'tokens': ['rancher', 'get', 'hempfed', 'beef', 'market', 'steak', 'high'],
#   'length': 7},
#  {'tokens': ['cannot', 'decide', 'consistent', 'workout', 'music', 'mix'],
#   'length': 6},
#  {'tokens': ['top', 'lung', 'luna', 'de', 'miel'], 'length': 5},
#  {'tokens': ['pro',
#    'athlete',
#    'test',
#    'bobbi',
#    'brown',
#    'new',
#    'makeup',
#    'line',
#    'prove',
#    'sweatproof'],
#   'length': 10},
#  {'tokens': ['feminist',
#    'least',
#    'favourite',
#    'math',
#    'topic',
#    'triggernometry'],
#   'length': 6},
#  {'tokens': ['decided', 'play', 'agario', 'hate', 'cellf'], 'length': 5},
#  {'tokens': ['never', 'understood', 'vet', 'called', 'dogtors'], 'length': 5},
#  {'tokens': ['north', 'korea', 'ban', 'sarcasm', 'great', 'idea'],
#   'length': 6},
#  {'tokens': ['g20',
#    'lay',
#    'plan',
#    'could',
#    'help',
#    'world',
#    'poor',
#    'leader',
#    'step'],
#   'length': 9},
#  {'tokens': ['okay', 'make', 'mess', 'thing'], 'length': 4},
#  {'tokens': ['asteroid',
#    'upcoming',
#    'brush',
#    'past',
#    'earth',
#    'nothing',
#    'worry'],
#   'length': 7},
#  {'tokens': ['call',
#    'midget',
#    'mexican',
#    'paragraph',
#    'since',
#    'full',
#    'essay'],
#   'length': 7},
#  {'tokens': ['rabbit', 'favorite', 'song', 'hoppy', 'birthday'], 'length': 5},
#  {'tokens': ['never', 'date', 'tennis', 'player', 'love', 'mean', 'nothing'],
#   'length': 7},
#  {'tokens': ['man',
#    'say',
#    'masturbates',
#    'naked',
#    'yard',
#    'mom',
#    'banned',
#    'porn',
#    'cop'],
#   'length': 9},
#  {'tokens': ['zombie', 'walk', 'bar', 'bartender', 'say', 'get', 'life'],
#   'length': 7},
#  {'tokens': ['11',
#    'race',
#    'horse',
#    '11',
#    '12',
#    '11',
#    '1',
#    '1',
#    'race',
#    '12',
#    '1',
#    '1',
#    '2'],
#   'length': 13},
#  {'tokens': ['general',
#    'electric',
#    'secures',
#    'first',
#    'myanmar',
#    'deal',
#    'sanction',
#    'ease'],
#   'length': 8},
#  {'tokens': ['gay', 'couple', 'favorite', 'fruit', 'cantaloupe'], 'length': 5},
#  {'tokens': ['disrupted', 'sleep', 'could', 'early', 'sign', 'alzheimers'],
#   'length': 6},
#  {'tokens': ['dog',
#    'attacking',
#    'garden',
#    'hose',
#    'slow',
#    'motion',
#    'weird',
#    'majestic'],
#   'length': 8},
#  {'tokens': ['planning',
#    'le',
#    'effective',
#    'juggling',
#    'multiple',
#    'goal',
#    'study'],
#   'length': 7},
#  {'tokens': ['meghan',
#    'trainor',
#    'performs',
#    'touching',
#    'tribute',
#    'christina',
#    'grimmie',
#    'new',
#    'york',
#    'show'],
#   'length': 10},
#  {'tokens': ['ian',
#    'mckellen',
#    'look',
#    'back',
#    'closeted',
#    'gay',
#    'youth',
#    'new',
#    'short',
#    'film'],
#   'length': 10},
#  {'tokens': ['african',
#    'say',
#    'hear',
#    'something',
#    'funny',
#    'fucking',
#    'malarious'],
#   'length': 7},
#  {'tokens': ['always', 'hear', 'voice', 'go', 'poo', 'shitzophrenia'],
#   'length': 6},
#  {'tokens': ['man', 'say', 'giant', 'squid', 'kraken', 'jajajajajjajjaja'],
#   'length': 6},
#  {'tokens': ['2013',
#    'national',
#    'geographic',
#    'traveler',
#    'photo',
#    'contest',
#    'receives',
#    'stunning',
#    'entry'],
#   'length': 9},
#  {'tokens': ['time', 'sean', 'connery', 'arrive', 'wimbledon', 'tennish'],
#   'length': 6},
#  {'tokens': ['jay',
#    'z',
#    'tidal',
#    'move',
#    'original',
#    'programming',
#    'comedy',
#    'series'],
#   'length': 8},
#  {'tokens': ['special',
#    'type',
#    'animal',
#    'turn',
#    'food',
#    'cross',
#    'something',
#    'chicken'],
#   'length': 8},
#  {'tokens': ['like',
#    'pizza',
#    'like',
#    'like',
#    'woman',
#    'hot',
#    'delivered',
#    'house'],
#   'length': 8},
#  {'tokens': ['shooting',
#    'reported',
#    '2',
#    'jewish',
#    'center',
#    'overland',
#    'park',
#    'kan',
#    'video'],
#   'length': 9},
#  {'tokens': ['best', 'time', 'buy', 'bird', 'go', 'cheep'], 'length': 6},
#  {'tokens': ['pirate',
#    'favrite',
#    'letter',
#    'aye',
#    'ye',
#    'think',
#    'rrrrr',
#    'c'],
#   'length': 8},
#  {'tokens': ['fired', 'sphere', 'maker', 'kept', 'cutting', 'corner'],
#   'length': 6},
#  {'tokens': ['jerry',
#    'brown',
#    'got',
#    'joe',
#    'biden',
#    'really',
#    'riled',
#    'health',
#    'care',
#    'rally'],
#   'length': 10},
#  {'tokens': ['everyone', 'friend', 'laugh', 'funnier', 'joke'], 'length': 5},
#  {'tokens': ['polish',
#    'joke',
#    'anyone',
#    'knock',
#    'knock',
#    'polish',
#    'burgular'],
#   'length': 7},
#  {'tokens': ['processed', 'food', 'bad'], 'length': 3},
#  {'tokens': ['started',
#    'new',
#    'job',
#    'yesterday',
#    'go',
#    'back',
#    'today',
#    'already',
#    'bullshit'],
#   'length': 9},
#  {'tokens': ['eating',
#    'cereal',
#    'shower',
#    'saving',
#    'much',
#    'time',
#    'thought'],
#   'length': 7},
#  {'tokens': ['surprise', 'coworkers', 'hiding', 'utility', 'closet', 'dead'],
#   'length': 6},
#  {'tokens': ['difference',
#    'jam',
#    'jelly',
#    'nsfw',
#    'cannot',
#    'jelly',
#    'dick',
#    'sister',
#    'as'],
#   'length': 9},
#  {'tokens': ['nyse',
#    'readying',
#    'plan',
#    'run',
#    'without',
#    'human',
#    'case',
#    'disaster',
#    'report'],
#   'length': 9},
#  {'tokens': ['like', 'kid', 'candy', 'store', 'cannot', 'afford', 'anything'],
#   'length': 7},
#  {'tokens': ['like',
#    'woman',
#    'like',
#    'like',
#    'milk',
#    'rich',
#    'white',
#    '2',
#    'fat'],
#   'length': 9},
#  {'tokens': ['chuck',
#    'norris',
#    'sex',
#    'every',
#    'woman',
#    'month',
#    'cause',
#    'week',
#    'bleeding'],
#   'length': 9},
#  {'tokens': ['ask', 'healthy', 'living', 'cannot', 'stop', 'eating', 'night'],
#   'length': 7},
#  {'tokens': ['cannot', 'threaten', 'work', 'came', 'work'], 'length': 5},
#  {'tokens': ['woman', 'walk', 'bar', 'ruin', 'joke'], 'length': 5},
#  {'tokens': ['know', 'fold', 'rethinking', 'america', 'strategy', 'iraq'],
#   'length': 6},
#  {'tokens': ['23', 'blast', 'based', 'amazing', 'true', 'story'], 'length': 6},
#  {'tokens': ['gop',
#    'lawmaker',
#    'stand',
#    'claim',
#    'islam',
#    'cancer',
#    'america'],
#   'length': 7},
#  {'tokens': ['bullying',
#    'prevention',
#    'program',
#    'may',
#    'negative',
#    'impact',
#    'study'],
#   'length': 7},
#  {'tokens': ['making', 'case', 'dating', 'bad', 'boy'], 'length': 5},
#  {'tokens': ['film', 'soul', 'healing', 'wartorn', 'spirit', 'watch'],
#   'length': 6},
#  {'tokens': ['disneyland',
#    'behindthescenes',
#    'photo',
#    'show',
#    'park',
#    'cast',
#    'member',
#    'view',
#    'photo'],
#   'length': 9},
#  {'tokens': ['heard',
#    'like',
#    'eight',
#    'cancer',
#    'joke',
#    'today',
#    'hear',
#    'another',
#    'one',
#    'going',
#    'benign'],
#   'length': 11},
#  {'tokens': ['sorry', 'grandma', 'love', 'fdaapproved', 'ingredient'],
#   'length': 5},
#  {'tokens': ['son',
#    'consider',
#    'bedtime',
#    'first',
#    'offer',
#    'negotiation',
#    'process'],
#   'length': 7},
#  {'tokens': ['simone',
#    'bile',
#    'serena',
#    'williams',
#    'look',
#    'fierce',
#    'af',
#    'new',
#    'nike',
#    'ad'],
#   'length': 10},
#  {'tokens': ['need', 'know', 'explosive', 'dinah', 'mite'], 'length': 5},
#  {'tokens': ['referenced',
#    'previous',
#    'girlfriend',
#    'academic',
#    'paper',
#    'exciting'],
#   'length': 6},
#  {'tokens': ['frumshrum',
#    'prediction',
#    'bibis',
#    'word',
#    'hillary',
#    'email',
#    'scotuss',
#    'obamacare',
#    'argument'],
#   'length': 9},
#  {'tokens': ['long',
#    'since',
#    'gotten',
#    'laid',
#    'sperm',
#    'starting',
#    'grow',
#    'leg'],
#   'length': 8},
#  {'tokens': ['email',
#    'raise',
#    'question',
#    'chicago',
#    'handling',
#    'rekia',
#    'boyd',
#    'shooting'],
#   'length': 8},
#  {'tokens': ['problem',
#    'commitment',
#    'never',
#    'mind',
#    'joke',
#    'lame',
#    'anyway'],
#   'length': 7},
#  {'tokens': ['call', 'suicidal', 'cat', 'curiosity'], 'length': 4},
#  {'tokens': ['chuck',
#    'todd',
#    'grill',
#    'ben',
#    'carson',
#    'love',
#    'nazi',
#    'metaphor'],
#   'length': 8},
#  {'tokens': ['believe', 'telekinesis', 'raise', 'hand'], 'length': 4},
#  {'tokens': ['sun', 'come', 'tomorrow', 'unfortunately', 'people'],
#   'length': 5},
#  {'tokens': ['deadly',
#    'bombing',
#    'niger',
#    'market',
#    'boko',
#    'haram',
#    'attack'],
#   'length': 7},
#  {'tokens': ['trump',
#    'may',
#    'avoid',
#    'pennsylvania',
#    'special',
#    'election',
#    'look',
#    'like',
#    'guy',
#    'lose'],
#   'length': 10},
#  {'tokens': ['compound',
#    'corydalis',
#    'chinese',
#    'medicine',
#    'plant',
#    'promising',
#    'chronic',
#    'pain',
#    'relief'],
#   'length': 9},
#  {'tokens': ['influence', 'influence', 'influence'], 'length': 3},
#  {'tokens': ['could', 'op', 'make', 'standup', 'comedian', 'poor', 'delivery'],
#   'length': 7},
#  {'tokens': ['q', 'difference', 'violin', 'viola', 'viola', 'burn', 'longer'],
#   'length': 7},
#  {'tokens': ['many', 'pig', 'die', 'whilst', 'eating', 'apple'], 'length': 6},
#  {'tokens': ['drug',
#    'company',
#    'using',
#    'electronic',
#    'health',
#    'record',
#    'sell',
#    'stuff'],
#   'length': 8},
#  {'tokens': ['cheating',
#    'sign',
#    '10',
#    'classic',
#    'sign',
#    'spouse',
#    'may',
#    'cheating'],
#   'length': 8},
#  {'tokens': ['actually',
#    'past',
#    'tense',
#    'hanged',
#    'hanged',
#    'sorry',
#    'dad',
#    'though'],
#   'length': 8},
#  {'tokens': ['catfight',
#    'clip',
#    'pause',
#    'anne',
#    'heche',
#    'sandra',
#    'oh',
#    'rivalry',
#    'quick',
#    'pregnancy',
#    'reveal'],
#   'length': 11},
#  {'tokens': ['russianiranian',
#    'arm',
#    'sale',
#    'repercussion',
#    'nuclear',
#    'talk'],
#   'length': 6},
#  {'tokens': ['police',
#    'say',
#    'oscar',
#    'pistorius',
#    'flight',
#    'risk',
#    'also',
#    'pair',
#    'propeller',
#    'foot'],
#   'length': 10},
#  {'tokens': ['silicon',
#    'valley',
#    'american',
#    'utopia',
#    'matter',
#    'peter',
#    'thiel',
#    'think'],
#   'length': 8},
#  {'tokens': ['french',
#    'muslim',
#    'working',
#    'french',
#    'security',
#    'al',
#    'qaeda'],
#   'length': 7},
#  {'tokens': ['katy',
#    'perry',
#    'russell',
#    'brand',
#    'divorce',
#    'comedian',
#    'unfollows',
#    'ex',
#    'twitter'],
#   'length': 9},
#  {'tokens': ['10', 'coolest', 'subway', 'around', 'world', 'photo'],
#   'length': 6},
#  {'tokens': ['top', '10', 'tip', 'plan', 'wedding', 'way'], 'length': 6},
#  {'tokens': ['okay', 'pluto', 'planet', 'either'], 'length': 4},
#  {'tokens': ['inspired', 'tribute', 'joan', 'river'], 'length': 4},
#  {'tokens': ['5', 'achievable', 'resolution', 'longer', 'happier', 'life'],
#   'length': 6},
#  {'tokens': ['trump',
#    'call',
#    'death',
#    'penalty',
#    'uzbek',
#    'immigrant',
#    'charged',
#    'new',
#    'york',
#    'city',
#    'attack'],
#   'length': 11},
#  {'tokens': ['group',
#    '12',
#    'year',
#    'old',
#    'girl',
#    'scared',
#    'boy',
#    'omg',
#    'tooooooo'],
#   'length': 9},
#  {'tokens': ['president',
#    'attack',
#    'people',
#    'color',
#    'using',
#    'page',
#    'white',
#    'supremacy',
#    'playbook'],
#   'length': 9},
#  {'tokens': ['help', 'slowly', 'turning', 'ghost', 'top', 'mr', 'butterworth'],
#   'length': 7},
#  {'tokens': ['mother', 'day', 'beauty', 'gift', '50', 'photo'], 'length': 6},
#  {'tokens': ['disability',
#    'right',
#    'advocate',
#    'champion',
#    'tom',
#    'perez',
#    'dnc',
#    'chair'],
#   'length': 8},
#  {'tokens': ['watch',
#    'manatee',
#    'drinking',
#    'water',
#    'hose',
#    'insane',
#    'looking',
#    'mouth'],
#   'length': 8},
#  {'tokens': ['one', 'fifth', 'people', 'tense'], 'length': 4},
#  {'tokens': ['gemma',
#    'redux',
#    'jewelry',
#    'score',
#    'blake',
#    'lively',
#    'favorite',
#    'photo'],
#   'length': 8},
#  {'tokens': ['call', 'fat', 'asian', 'moolan'], 'length': 4},
#  {'tokens': ['donald',
#    'trump',
#    'think',
#    'health',
#    'care',
#    'plan',
#    'singlepayer'],
#   'length': 7},
#  {'tokens': ['last',
#    'thing',
#    'go',
#    'bug',
#    'mind',
#    'hit',
#    'car',
#    'windshield',
#    'butt'],
#   'length': 9},
#  {'tokens': ['backed',
#    'horse',
#    '101',
#    'yesterday',
#    'came',
#    'quarter',
#    'past',
#    '4'],
#   'length': 8},
#  {'tokens': ['vincent',
#    'kartheiser',
#    'mr',
#    'darcy',
#    'mad',
#    'men',
#    'star',
#    'look',
#    'like',
#    'mutton',
#    'chop',
#    'photo'],
#   'length': 12},
#  {'tokens': ['pirate',
#    'say',
#    'successful',
#    'pillage',
#    'thanks',
#    'gold',
#    'kind',
#    'stranger'],
#   'length': 8},
#  {'tokens': ['child',
#    'custody',
#    'celebrity',
#    'dad',
#    'got',
#    'custody',
#    'kid',
#    'photo'],
#   'length': 8},
#  {'tokens': ['ever',
#    'smelled',
#    'moth',
#    'ball',
#    'get',
#    'tiny',
#    'little',
#    'leg',
#    'apart'],
#   'length': 9},
#  {'tokens': ['pull',
#    'away',
#    'kissing',
#    'judge',
#    'unexpected',
#    'kind',
#    'nice',
#    'still',
#    'guilty'],
#   'length': 9},
#  {'tokens': ['story', 'listen', 'body', 'find', 'doctor', 'listen'],
#   'length': 6},
#  {'tokens': ['tie', 'say', 'hat', 'go', 'ahead', 'hang', 'around'],
#   'length': 7},
#  {'tokens': ['man',
#    'sure',
#    'mad',
#    'rising',
#    'bullet',
#    'price',
#    'get',
#    'le',
#    'bang',
#    'buck'],
#   'length': 10},
#  {'tokens': ['cannot', 'fool', 'aborted', 'baby', 'born', 'yesterday'],
#   'length': 6},
#  {'tokens': ['stock', 'home', 'bar', '100'], 'length': 4},
#  {'tokens': ['cmt',
#    'award',
#    '2012',
#    'red',
#    'carpet',
#    'full',
#    'glitter',
#    'boot',
#    'photo'],
#   'length': 9},
#  {'tokens': ['cowboy',
#    'get',
#    'daschund',
#    'wanted',
#    'get',
#    'long',
#    'little',
#    'doggie'],
#   'length': 8},
#  {'tokens': ['happy', 'easter', 'jew', 'better', 'luck', 'next', 'time'],
#   'length': 7},
#  {'tokens': ['puppy', 'thoroughly', 'amazed', 'first', 'encounter', 'rain'],
#   'length': 6},
#  {'tokens': ['call', 'online', 'relationship', 'ebae', 'see'], 'length': 5},
#  {'tokens': ['obama',
#    'give',
#    'shoutout',
#    'equal',
#    'pay',
#    'honoring',
#    '2015',
#    'wnba',
#    'champ'],
#   'length': 9},
#  {'tokens': ['ramadan', 'time', 'get', 'date', 'every', 'night'], 'length': 6},
#  {'tokens': ['thank',
#    'goodness',
#    'loyalty',
#    'program',
#    'email',
#    'keep',
#    'forgetting',
#    'brand',
#    'loyal'],
#   'length': 9},
#  {'tokens': ['two', 'woman', 'got', 'power', 'visit', 'tbt', 'history'],
#   'length': 7},
#  {'tokens': ['one',
#    'size',
#    'fit',
#    'correcting',
#    'muslim',
#    'woman',
#    'empowerment',
#    'training',
#    'end',
#    'terrorism'],
#   'length': 10},
#  {'tokens': ['found', 'spaghetti', 'heating', 'duct', 'thinking', 'child'],
#   'length': 6},
#  {'tokens': ['attitude', 'personality', 'cannot', 'handle'], 'length': 4},
#  {'tokens': ['deodorant',
#    'never',
#    'needed',
#    'buy',
#    'people',
#    'give',
#    'complete',
#    'stranger',
#    'sometimes'],
#   'length': 9},
#  {'tokens': ['baby', 'cannot', 'get', 'hang', 'whole', 'christmas', 'thing'],
#   'length': 7},
#  {'tokens': ['emmelie',
#    'gustafsson',
#    'intern',
#    'unusual',
#    'use',
#    'flat',
#    'iron'],
#   'length': 7},
#  {'tokens': ['two', 'wrong', 'make', 'right', 'take', 'parent', 'example'],
#   'length': 7},
#  {'tokens': ['beyond',
#    'symbolism',
#    'restoring',
#    'tie',
#    'cuba',
#    'practical',
#    'benefit'],
#   'length': 7},
#  {'tokens': ['ucla',
#    'football',
#    'team',
#    'go',
#    'banana',
#    'teammate',
#    'pop',
#    'question',
#    'gif'],
#   'length': 9},
#  {'tokens': ['little', 'boy', 'flush', 'pencil', 'toilet', 'number', '2'],
#   'length': 7},
#  {'tokens': ['tim',
#    'burton',
#    'dark',
#    'shadow',
#    'dictator',
#    'common',
#    'law',
#    'week',
#    'ouch'],
#   'length': 9},
#  {'tokens': ['funny', 'think', 'cat', 'leaving', 'dead', 'bird', 'doorstep'],
#   'length': 7},
#  {'tokens': ['thanks',
#    'probably',
#    'start',
#    'seeing',
#    'display',
#    'sign',
#    'toilet',
#    'home',
#    'depot'],
#   'length': 9},
#  {'tokens': ['navy', 'navy', 'separate', 'men', 'boy', 'crowbar'],
#   'length': 6},
#  {'tokens': ['cannibal', 'hear', 'cannibal', 'passed', 'friend', 'forest'],
#   'length': 6},
#  {'tokens': ['iphone',
#    '5',
#    'preorders',
#    'ipad',
#    'mini',
#    'prediction',
#    'apple',
#    'tv',
#    'week',
#    'apple',
#    'rumor'],
#   'length': 11},
#  {'tokens': ['gmo',
#    'debate',
#    'heat',
#    'critic',
#    'say',
#    'biotech',
#    'industry',
#    'manipulating',
#    'gene',
#    'science'],
#   'length': 10},
#  {'tokens': ['dear',
#    'youtube',
#    'please',
#    'assume',
#    'would',
#    'like',
#    'skip',
#    'ad',
#    'need',
#    'ask',
#    'anymore'],
#   'length': 11},
#  {'tokens': ['way', 'empire', 'finale', 'set', 'season', '2'], 'length': 6},
#  {'tokens': ['favorite', 'u', 'state', 'miley', 'cyrus', 'montana'],
#   'length': 6},
#  {'tokens': ['isabel',
#    'celis',
#    'father',
#    'missing',
#    'arizona',
#    'girl',
#    'barred',
#    'contact',
#    'son',
#    'video'],
#   'length': 10},
#  {'tokens': ['hear', 'kidnapping', 'dallas', 'woke'], 'length': 4},
#  {'tokens': ['traditional',
#    'marriage',
#    'boy',
#    'parent',
#    'girl',
#    'parent',
#    'maybe',
#    'cattle'],
#   'length': 8},
#  {'tokens': ['memorial', 'day', 'musing', 'iraq', 'war', 'vet'], 'length': 6},
#  {'tokens': ['call', 'prematurely', 'born', 'chinese', 'boy', 'sudden', 'lee'],
#   'length': 7},
#  {'tokens': ['men', 'pig', 'misandrist', 'world', 'worst', 'biologist'],
#   'length': 6},
#  {'tokens': ['favorite', 'christmas', 'cookie', 'say'], 'length': 4},
#  {'tokens': ['like',
#    'woman',
#    'like',
#    'heroin',
#    'smuggled',
#    'tiny',
#    'box',
#    'south',
#    'east',
#    'asia'],
#   'length': 10},
#  {'tokens': ['diagnosing',
#    'home',
#    'alone',
#    'burglar',
#    'injury',
#    'professional',
#    'weighs'],
#   'length': 7},
#  {'tokens': ['george',
#    'clooney',
#    'amal',
#    'alamuddin',
#    'make',
#    'redcarpet',
#    'official'],
#   'length': 7},
#  {'tokens': ['jim',
#    'carrey',
#    'make',
#    'brian',
#    'williams',
#    'joke',
#    'snl',
#    '40',
#    'red',
#    'carpet'],
#   'length': 10},
#  {'tokens': ['officer', 'put', 'phone', 'soon', 'saw', 'saw', 'using'],
#   'length': 7},
#  {'tokens': ['student', 'loan', 'victim', 'pay', 'price', 'ed', 'inaction'],
#   'length': 7},
#  {'tokens': ['buying', 'bulk', 'food', 'item', 'buy', 'warehouse', 'store'],
#   'length': 7},
#  {'tokens': ['baby', 'cry', 'much', 'mom'], 'length': 4},
#  {'tokens': ['supreme',
#    'court',
#    'decision',
#    'benefit',
#    'people',
#    'mental',
#    'illness'],
#   'length': 7},
#  {'tokens': ['illegally',
#    'watched',
#    'hang',
#    'part',
#    '3',
#    'online',
#    'still',
#    'feel',
#    'like',
#    'got',
#    'ripped'],
#   'length': 11},
#  {'tokens': ['worst', 'part', 'cumming', '2', 'mintues', 'spooning'],
#   'length': 6},
#  {'tokens': ['big', 'hairy', 'fly', 'king', 'kongcorde'], 'length': 5},
#  {'tokens': ['would',
#    'absolutely',
#    'say',
#    'introvert',
#    'guy',
#    'screaming',
#    'table',
#    'full',
#    'friend',
#    'brunch'],
#   'length': 10},
#  {'tokens': ['paul', 'ryan', 'opinion', 'stopandfrisk', 'policy'],
#   'length': 5},
#  {'tokens': ['think',
#    'vegetarian',
#    'make',
#    'thin',
#    'direct',
#    'attention',
#    'cow'],
#   'length': 7},
#  {'tokens': ['short',
#    'model',
#    'kate',
#    'moss',
#    'devon',
#    'aoki',
#    'face',
#    'star',
#    'supermodel',
#    '58'],
#   'length': 10},
#  {'tokens': ['cooperative', 'target', 'would', 'like', 'apologizing'],
#   'length': 5},
#  {'tokens': ['lobster', 'say', 'saw', 'mermaid', 'got', 'lay', 'seaweed'],
#   'length': 7},
#  {'tokens': ['75', 'ball', 'screw', 'old', 'lady', 'bingo'], 'length': 6},
# ...
#    'near',
#    'police',
#    'dog',
#    'training',
#    'center',
#    'cop'],
#   'length': 9},
#  {'tokens': ['complete', 'star', 'war', 'timeline', 'one', 'infographic'],
#   'length': 6},
#  {'tokens': ['made',
#    'quality',
#    'assurance',
#    'supervisor',
#    'amazon',
#    'warehouse',
#    'laugh'],
#   'length': 7},
#  {'tokens': ['9', 'gorgeous', 'field', 'flower', 'worth', 'traveling', 'see'],
#   'length': 7},
#  {'tokens': ['attacker',
#    'sentenced',
#    '3',
#    'year',
#    'prison',
#    'hate',
#    'crime',
#    'sikh',
#    'man'],
#   'length': 9},
#  {'tokens': ['little', 'piggy', 'dancing', 'rihannas', 'work', 'make', 'day'],
#   'length': 7},
#  {'tokens': ['ride', 'escalator', 'step', '1', 'chill', 'bit'], 'length': 6},
#  {'tokens': ['wife', 'freak', 'sperm', 'get', 'face', 'hair', 'sister'],
#   'length': 7},
#  {'tokens': ['think', 'bad', 'one', 'snowiest', 'place', 'earth'],
#   'length': 6},
#  {'tokens': ['bbq',
#    'pork',
#    'meatball',
#    'lower',
#    'east',
#    'side',
#    'bbq',
#    'sauce'],
#   'length': 8},
#  {'tokens': ['coworker',
#    'give',
#    '20',
#    'minute',
#    'dissertation',
#    'gastro',
#    'infection'],
#   'length': 7},
#  {'tokens': ['yao', 'ming', 'stand', 'sits', 'take', 'long', 'get', 'back'],
#   'length': 8},
#  {'tokens': ['scandalous', '31', 'million', 'girl', 'receive', 'education'],
#   'length': 6},
#  {'tokens': ['call', 'black', 'man', 'moon', 'astronaut'], 'length': 5},
#  {'tokens': ['old',
#    'dude',
#    'europe',
#    'everywhere',
#    'one',
#    'making',
#    'everybody',
#    'cry'],
#   'length': 8},
#  {'tokens': ['art', 'receiving', 'different', 'act', 'taking'], 'length': 5},
#  {'tokens': ['5', 'step', 'strong', 'alignment', 'upward', 'salute'],
#   'length': 6},
#  {'tokens': ['male', 'rock', 'group', 'sing', 'mount', 'rushmore'],
#   'length': 6},
#  {'tokens': ['romance', 'politics', 'four', 'season', 'washington', 'dc'],
#   'length': 6},
#  {'tokens': ['mike',
#    'huckabee',
#    'jokingly',
#    'break',
#    'campaign',
#    'finance',
#    'law',
#    '2016',
#    'announcement'],
#   'length': 9},
#  {'tokens': ['kim',
#    'kardashian',
#    'brings',
#    'back',
#    'cargo',
#    'pocket',
#    '2015',
#    'vmas'],
#   'length': 8},
#  {'tokens': ['programmer', 'hate', 'fat', 'woman', 'fat', 'finger'],
#   'length': 6},
#  {'tokens': ['nutritional',
#    'value',
#    'entire',
#    'tube',
#    'cherry',
#    'chapstick',
#    'asking',
#    'two',
#    'year',
#    'old'],
#   'length': 10},
#  {'tokens': ['yo', 'mama', 'teeth', 'yellow', 'cannot', 'believe', 'butter'],
#   'length': 7},
#  {'tokens': ['19yearold',
#    'sentenced',
#    'beating',
#    'homeless',
#    'man',
#    'death',
#    'drunken',
#    'rage'],
#   'length': 8},
#  {'tokens': ['whoopi',
#    'goldberg',
#    'iconic',
#    'word',
#    'tiffany',
#    'haddish',
#    'hosted',
#    'snl'],
#   'length': 8},
#  {'tokens': ['come', 'plane', 'make', 'plane', 'noise', 'spoon', 'disappears'],
#   'length': 7},
#  {'tokens': ['woman', 'trump', 'female', 'fan', 'speak'], 'length': 5},
#  {'tokens': ['changed',
#    'sex',
#    'daughter',
#    'ignoring',
#    'seems',
#    'like',
#    'transparent'],
#   'length': 7},
#  {'tokens': ['call', 'kitten', 'accidentally', 'eat', 'pill', 'caterpillar'],
#   'length': 6},
#  {'tokens': ['best',
#    'brisket',
#    'texas',
#    'franklin',
#    'bbq',
#    'plus',
#    'make',
#    'hill',
#    'country',
#    'brisket'],
#   'length': 10},
#  {'tokens': ['guy', 'pen', 'cheeky', 'obituary', 'gone'], 'length': 5},
#  {'tokens': ['best',
#    'kiss',
#    'life',
#    'vacuum',
#    'cleaner',
#    'took',
#    'breath',
#    'away'],
#   'length': 8},
#  {'tokens': ['people', 'fiji', 'know', 'pay', '4', 'dollar', 'tap', 'water'],
#   'length': 8},
#  {'tokens': ['call', 'story', 'broken', 'pencil', 'pointless'], 'length': 5},
#  {'tokens': ['garden',
#    'wall',
#    'idea',
#    'plant',
#    'become',
#    'interior',
#    'decor',
#    'video'],
#   'length': 8},
#  {'tokens': ['peter', 'pan', 'fly', 'neverlands'], 'length': 4},
#  {'tokens': ['airline', 'infuse', 'plane', 'smell', 'calm', 'make', 'love'],
#   'length': 7},
#  {'tokens': ['oedipus', 'slip', 'say', 'one', 'thing', 'fuck', 'mother'],
#   'length': 7},
#  {'tokens': ['man',
#    'balk',
#    'war',
#    'discharged',
#    'dereliction',
#    'duty',
#    'take',
#    'drinking'],
#   'length': 8},
#  {'tokens': ['call', 'mexican', 'cannot', 'find', 'vehicle', 'carlos'],
#   'length': 6},
#  {'tokens': ['terrifying',
#    'clip',
#    'show',
#    'never',
#    'run',
#    'tree',
#    'thunderstorm'],
#   'length': 7},
#  {'tokens': ['happens', 'ear', 'sex', 'get', 'hearing', 'aid'], 'length': 6},
#  {'tokens': ['thane', 'alphabet', 'grateful', 'thane', 'q'], 'length': 5},
#  {'tokens': ['many', 'foot', 'yard', 'depends', 'many', 'people', 'standing'],
#   'length': 7},
#  {'tokens': ['difference',
#    'donald',
#    'trump',
#    'mr',
#    'smith',
#    'mr',
#    'smith',
#    'went',
#    'washington'],
#   'length': 9},
#  {'tokens': ['state',
#    'eye',
#    'new',
#    'way',
#    'dampen',
#    'corporate',
#    'political',
#    'spending'],
#   'length': 8},
#  {'tokens': ['mental', 'health', 'expert', 'say', 'presidency'], 'length': 5},
#  {'tokens': ['patagonia',
#    'join',
#    'coalition',
#    'suing',
#    'block',
#    'trump',
#    'federal',
#    'land',
#    'cut'],
#   'length': 9},
#  {'tokens': ['michelle',
#    'williams',
#    'busy',
#    'philipps',
#    'ultimate',
#    'red',
#    'carpet',
#    'bffs'],
#   'length': 8},
#  {'tokens': ['cure', 'kleptomania', 'make', 'pilfer'], 'length': 4},
#  {'tokens': ['call', 'affectionate', 'rabbit', 'tender', 'loving', 'hare'],
#   'length': 6},
#  {'tokens': ['workout', 'like', 'warm', '10', 'set', 'selfies'], 'length': 6},
#  {'tokens': ['simple',
#    'strategy',
#    'helped',
#    'maine',
#    'achieve',
#    'nation',
#    'highest',
#    'vaccination',
#    'rate',
#    'toddler'],
#   'length': 10},
#  {'tokens': ['red',
#    'list',
#    'endangered',
#    'ecosystem',
#    'proposed',
#    'international',
#    'union',
#    'conservation',
#    'nature'],
#   'length': 9},
#  {'tokens': ['giant',
#    'floating',
#    'whale',
#    'carcass',
#    'could',
#    'attract',
#    'shark',
#    'close',
#    'hawaii',
#    'shore'],
#   'length': 10},
#  {'tokens': ['usa',
#    'going',
#    'backward',
#    '1',
#    '6',
#    'american',
#    'lack',
#    'insurance',
#    'decade',
#    'like',
#    'crisis',
#    '2009'],
#   'length': 12},
#  {'tokens': ['world',
#    'first',
#    'diamond',
#    'ring',
#    '150',
#    'carat',
#    'pure',
#    'unadulterated',
#    'bling',
#    'photo',
#    'video'],
#   'length': 11},
#  {'tokens': ['hear', 'jew', 'started', 'charity', 'neither'], 'length': 5},
#  {'tokens': ['lorde',
#    'shuts',
#    'rumor',
#    'dating',
#    'jack',
#    'antonoff',
#    'lena',
#    'dunhams',
#    'ex'],
#   'length': 9},
#  {'tokens': ['larry', 'wilmore', 'milo', 'yiannopoulos', 'go', 'fk'],
#   'length': 6},
#  {'tokens': ['msnbc',
#    'give',
#    'disingenuous',
#    'rightwing',
#    'smear',
#    'fire',
#    'sam',
#    'seder'],
#   'length': 8},
#  {'tokens': ['life', 'lesson', 'lottery', 'people', 'separated', 'divorced'],
#   'length': 6},
#  {'tokens': ['deal', 'hairline', 'food', 'mean', 'sheariously'], 'length': 5},
#  {'tokens': ['kind', 'leash', 'buy', 'chihuahua', 'short', 'one'],
#   'length': 6},
#  {'tokens': ['rose', 'red', 'violet', 'blue', 'poem', 'rhyme', 'one'],
#   'length': 7},
#  {'tokens': ['michael',
#    'jackson',
#    'santa',
#    'clause',
#    'common',
#    'like',
#    'come',
#    'shoot'],
#   'length': 8},
#  {'tokens': ['tree', 'say', 'autumn', 'leaf', 'alone'], 'length': 5},
#  {'tokens': ['84',
#    'great',
#    'dane',
#    'rescued',
#    'new',
#    'hampshire',
#    'worst',
#    'squalor'],
#   'length': 8},
#  {'tokens': ['accidentally',
#    'dumped',
#    'white',
#    'flour',
#    'black',
#    'labrador',
#    'greyhound'],
#   'length': 7},
#  {'tokens': ['police',
#    'kill',
#    'armed',
#    'black',
#    'man',
#    'st',
#    'louis',
#    'anniversary',
#    'another',
#    'officerinvolved',
#    'shooting'],
#   'length': 11},
#  {'tokens': ['starting',
#    'website',
#    'called',
#    'kickfarter',
#    'people',
#    'pay',
#    'fart'],
#   'length': 7},
#  {'tokens': ['wish',
#    'half',
#    'determination',
#    'persistence',
#    'adobe',
#    'reader',
#    'updater'],
#   'length': 7},
#  {'tokens': ['even',
#    'aca',
#    'health',
#    'insurer',
#    'playing',
#    'god',
#    'come',
#    'opioid',
#    'addiction'],
#   'length': 9},
#  {'tokens': ['colin',
#    'farrell',
#    'amazing',
#    'plea',
#    'marriage',
#    'equality',
#    'behalf',
#    'gay',
#    'brother'],
#   'length': 9},
#  {'tokens': ['willow',
#    'smith',
#    'zendaya',
#    'breathe',
#    'new',
#    'life',
#    'david',
#    'bowie',
#    'change'],
#   'length': 9},
#  {'tokens': ['syrian',
#    'opposition',
#    'activist',
#    'daughter',
#    'murdered',
#    'istanbul'],
#   'length': 6},
#  {'tokens': ['life', 'like', 'box', 'chocolate', 'load', 'shit'], 'length': 6},
#  {'tokens': ['call', 'small', 'parent', 'minimum'], 'length': 4},
#  {'tokens': ['lesson',
#    'dr',
#    'kim',
#    'world',
#    'bank',
#    'ponders',
#    'kosovo',
#    'coal',
#    'project'],
#   'length': 9},
#  {'tokens': ['programming', 'language', 'got', 'sex', 'change', 'fortranny'],
#   'length': 6},
#  {'tokens': ['bernie',
#    'sander',
#    'business',
#    'model',
#    'wall',
#    'street',
#    'fraud'],
#   'length': 7},
#  {'tokens': ['friend', 'like', 'snowflake', 'pee', 'disappear'], 'length': 5},
#  {'tokens': ['donald',
#    'trump',
#    'reportedly',
#    'considering',
#    'fast',
#    'food',
#    'ceo',
#    'labor',
#    'secretary'],
#   'length': 9},
#  {'tokens': ['took', 'beauty', 'supplement', 'see', 'instagram'], 'length': 5},
#  {'tokens': ['american',
#    'insult',
#    'must',
#    'awkward',
#    'french',
#    'word',
#    'douche',
#    'douchebag',
#    'translates',
#    'shower'],
#   'length': 10},
#  {'tokens': ['new', 'year', 'new', 'semester', 'college', 'prep', 'junior'],
#   'length': 7},
#  {'tokens': ['always', 'thought', 'shih', 'tzu', 'zoo', 'without', 'animal'],
#   'length': 7},
#  {'tokens': ['market',
#    'warrior',
#    'pb',
#    'come',
#    'new',
#    'york',
#    'city',
#    'antique',
#    'garage',
#    'video'],
#   'length': 10},
#  {'tokens': ['iraq', 'war', 'led', 'paris', 'attack'], 'length': 5},
#  {'tokens': ['tickle',
#    'imaginary',
#    'friend',
#    'people',
#    'think',
#    'casting',
#    'spell'],
#   'length': 7},
#  {'tokens': ['matt', 'robert', 'former', '3', 'door', 'guitarist', 'dy', '38'],
#   'length': 8},
#  {'tokens': ['veteran',
#    'reportedly',
#    'helped',
#    'guide',
#    'dozen',
#    'safety',
#    'orlando',
#    'shooting'],
#   'length': 8},
#  {'tokens': ['fifthgrader',
#    'nail',
#    'whitney',
#    'houston',
#    'classic',
#    'talent',
#    'show'],
#   'length': 7},
#  {'tokens': ['business',
#    'sell',
#    'crucifix',
#    'shaped',
#    'ski',
#    'called',
#    'cross',
#    'country'],
#   'length': 8},
#  {'tokens': ['top',
#    'chef',
#    'fan',
#    'favorite',
#    'fabio',
#    'viviani',
#    'cooking',
#    'pasta'],
#   'length': 8},
#  {'tokens': ['american',
#    'favorite',
#    'kind',
#    'exercise',
#    'simple',
#    'solo',
#    'short'],
#   'length': 7},
#  {'tokens': ['someone',
#    'bring',
#    'soup',
#    'every',
#    'hot',
#    'girl',
#    'cold',
#    'ever'],
#   'length': 8},
#  {'tokens': ['princess',
#    'elisabeth',
#    'denmark',
#    'look',
#    'cute',
#    'rare',
#    'family',
#    'portrait',
#    'photo'],
#   'length': 9},
#  {'tokens': ['indian',
#    'social',
#    'medium',
#    'rage',
#    'snapchat',
#    'lawsuit',
#    'claim',
#    'ceo',
#    'called',
#    'country',
#    'poor'],
#   'length': 11},
#  {'tokens': ['doctor',
#    'doctor',
#    'feel',
#    'like',
#    'spoon',
#    'well',
#    'sit',
#    'still',
#    'stir'],
#   'length': 9},
#  {'tokens': ['john', 'memory', 'bad', 'george', 'bad', 'john', 'bad'],
#   'length': 7},
#  {'tokens': ['weird',
#    'strategy',
#    'dr',
#    'seuss',
#    'used',
#    'create',
#    'greatest',
#    'work',
#    'use'],
#   'length': 9},
#  {'tokens': ['feel', 'younger', 'year', 'without', 'facelift'], 'length': 5},
#  {'tokens': ['oscar',
#    'pistorius',
#    'want',
#    'install',
#    'new',
#    'bathroom',
#    'door',
#    'girlfriend',
#    'dead'],
#   'length': 9},
#  {'tokens': ['new',
#    'york',
#    'fashion',
#    'week',
#    'street',
#    'style',
#    'favorite',
#    'look',
#    'day',
#    '1',
#    '2',
#    'photo'],
#   'length': 12},
#  {'tokens': ['trump',
#    'judicial',
#    'nominee',
#    'drop',
#    'embarrassing',
#    'hearing'],
#   'length': 6},
#  {'tokens': ['10', 'tip', 'make', 'kid', 'good', 'gift', 'giver'],
#   'length': 7},
#  {'tokens': ['difference',
#    'white',
#    'baby',
#    'black',
#    'baby',
#    '20',
#    'minute',
#    'thermostat',
#    '8'],
#   'length': 9},
#  {'tokens': ['feared', 'killer', 'whale', 'one', 'done', 'time', 'seaworld'],
#   'length': 7},
#  {'tokens': ['doe',
#    'walk',
#    'bar',
#    'keep',
#    'falling',
#    'cannot',
#    'walk',
#    'shit'],
#   'length': 8},
#  {'tokens': ['age', 'consent', 'thailand', '50'], 'length': 4},
#  {'tokens': ['japan', 'avocado', 'cheese', 'doritos', 'share', 'u', 'photo'],
#   'length': 7},
#  {'tokens': ['would', 'anything', 'vet', 'except', 'support', 'politics'],
#   'length': 6},
#  {'tokens': ['looking',
#    'funniest',
#    'short',
#    'joke',
#    'ever',
#    'short',
#    'small',
#    'short',
#    'short'],
#   'length': 9},
#  {'tokens': ['going', 'tell', 'joke', 'woman', 'right', 'would', 'funny'],
#   'length': 7},
#  {'tokens': ['tom',
#    'cruise',
#    'makeup',
#    'rock',
#    'age',
#    'frightened',
#    '6yearold',
#    'suri',
#    'cruise',
#    'photo'],
#   'length': 10},
#  {'tokens': ['9',
#    'secret',
#    'making',
#    'homemade',
#    'smoothy',
#    'taste',
#    'good',
#    'pro'],
#   'length': 8},
#  {'tokens': ['10', 'reason', 'every', 'athlete', 'world', 'meditate'],
#   'length': 6},
#  {'tokens': ['8', 'piece', 'real', 'advice', 'new', 'mom'], 'length': 6},
#  {'tokens': ['lgbtq',
#    'alabamian',
#    'played',
#    'crucial',
#    'role',
#    'spurring',
#    'turnout',
#    'roy',
#    'moore'],
#   'length': 9},
#  {'tokens': ['dog',
#    'lost',
#    'tail',
#    'go',
#    'get',
#    'new',
#    'one',
#    'retail',
#    'store'],
#   'length': 9},
#  {'tokens': ['stunning',
#    'city',
#    'skyline',
#    'give',
#    'another',
#    'reason',
#    'travel',
#    'world',
#    'right'],
#   'length': 9},
#  {'tokens': ['white', 'bottom', 'black', 'top', 'rape'], 'length': 5},
#  {'tokens': ['fearless', 'shopping', 'car'], 'length': 3},
#  {'tokens': ['local',
#    'psychic',
#    'closed',
#    'due',
#    'unforeseen',
#    'circumstance'],
#   'length': 6},
#  {'tokens': ['truly', 'awful', 'part', 'food', 'allergy', 'got'], 'length': 6},
#  {'tokens': ['flotus', 'went', 'south', 'side', 'chicago', 'white', 'house'],
#   'length': 7},
#  {'tokens': ['craft',
#    'day',
#    'create',
#    'halloween',
#    'skull',
#    'plate',
#    'paper',
#    'napkin'],
#   'length': 8},
#  {'tokens': ['fail',
#    'urine',
#    'test',
#    'clean',
#    'sample',
#    'poop',
#    'specimen',
#    'cup'],
#   'length': 8},
#  {'tokens': ['500', 'dead', 'congo', 'cholera', 'epidemic', 'spread'],
#   'length': 6},
#  {'tokens': ['michelle',
#    'obama',
#    'talk',
#    'travel',
#    'america',
#    'place',
#    'want',
#    'see',
#    'video',
#    'photo'],
#   'length': 10},
#  {'tokens': ['bernie', 'sander', 'support', 'reparation', 'surprising'],
#   'length': 5},
#  {'tokens': ['snowman', 'smile', 'saw', 'snowblower', 'coming'], 'length': 5},
#  {'tokens': ['youngest',
#    'daughter',
#    'cannibalistic',
#    'family',
#    'late',
#    'dinner',
#    'got',
#    'cold',
#    'shoulder'],
#   'length': 9},
#  {'tokens': ['kurt',
#    'cobains',
#    'eye',
#    'color',
#    'blue',
#    'one',
#    'blue',
#    'left',
#    'one',
#    'blue',
#    'right'],
#   'length': 11},
#  {'tokens': ['germany',
#    'ban',
#    'islamist',
#    'group',
#    'conduct',
#    'nearly',
#    '200',
#    'raid'],
#   'length': 8},
#  {'tokens': ['signal', 'tell', 'politician', 'lying', 'lip', 'moving'],
#   'length': 6},
#  {'tokens': ['day', 'care', 'may', 'good', 'kid', 'mental', 'health', 'study'],
#   'length': 8},
#  {'tokens': ['drink', 'enough', 'brain', 'start', 'photoshopping', 'people'],
#   'length': 6},
#  {'tokens': ['scott',
#    'walker',
#    'open',
#    'building',
#    'wall',
#    'along',
#    'border',
#    'canada'],
#   'length': 8},
#  {'tokens': ['hell', 'eternity', 'sober', 'room', 'full', 'drunk', 'people'],
#   'length': 7},
#  {'tokens': ['malia',
#    'obamas',
#    'two',
#    'bun',
#    'great',
#    'plane',
#    'hairstyle',
#    'photo'],
#   'length': 8},
#  {'tokens': ['yahoo',
#    'third',
#    'point',
#    'square',
#    'proxy',
#    'fight',
#    'despite',
#    'three',
#    'new',
#    'independent',
#    'board',
#    'director'],
#   'length': 12},
#  ...]

# %%
X_valid = np.array([tokenize(x, tokenizer, max_length) for x in valid_features_numpy])
X_valid
# Out:
# array([{'tokens': ['heroic', 'food', 'truck', 'coming', 'rescue', 'california', 'fire', 'victim'], 'length': 8},
#        {'tokens': ['gay', 'friend', 'must', 'businessmen', 'keep', 'talking', 'partner'], 'length': 7},
#        {'tokens': ['jada', 'pinkett', 'smith', 'share', 'relationship', 'advice', 'facebook'], 'length': 7},
#        ...,
#        {'tokens': ['happens', 'mix', 'world', 'greatest', 'drug', 'booze'], 'length': 6},
#        {'tokens': ['general', 'patton', 'thanksgiving', 'gave', 'tank'], 'length': 5},
#        {'tokens': ['blink', '182', 'album', 'rereleased', 'cassette', 'tape'], 'length': 6}],
#       dtype=object)

# %%
X_test = np.array([tokenize(x[0], tokenizer, max_length) for x in test_features_numpy])
X_test
# Out:
# array([{'tokens': ['thought', 'reddit', 'joke', 'today', 'triangle', 'rectangle', 'fails'], 'length': 7},
#        {'tokens': ['much', 'pirate', 'pay', 'corn', 'buck', 'ear'], 'length': 6},
#        {'tokens': ['hillary', 'clinton', 'sent', 'book', 'every', 'gop', 'candidateexcept', 'one'], 'length': 8},
#        ...,
#        {'tokens': ['best', 'drug', 'sex', 'birth', 'control'], 'length': 5},
#        {'tokens': ['fit', 'link', 'tony', 'hortons', 'rule', 'gym', 'success', 'first', 'yoga', 'class'], 'length': 10},
#        {'tokens': ['positive', 'prognosis', 'climate', 'negotiation'], 'length': 4}],
#       dtype=object)

# %% [markdown]
# Build a vocabulary to numericalize the text data on

# %%
min_freq = 5
special_tokens = ["<unk>", "<pad>"] # <pad> to pad sequences when they are not long enough

vocab = build_vocab_from_iterator(
    [x['tokens'] for x in X_train], # get only the tokens of each element
    min_freq=min_freq,
    specials=special_tokens,
)

# %%
vocab.get_itos()
# Out:
# ['<unk>',
#  '<pad>',
#  'like',
#  'call',
#  'say',
#  'get',
#  'trump',
#  'new',
#  'photo',
#  'one',
#  'woman',
#  'people',
#  'make',
#  'know',
#  'day',
#  'would',
#  'man',
#  'time',
#  'go',
#  'want',
#  'joke',
#  'video',
#  'cannot',
#  'take',
#  'year',
#  'donald',
#  'thing',
#  'way',
#  'could',
#  'black',
#  'got',
#  'best',
#  'life',
#  'kid',
#  'never',
#  'girl',
#  'first',
#  'two',
#  'guy',
#  'love',
#  'look',
#  'good',
#  'world',
#  'hear',
#  'show',
#  'really',
#  'think',
#  'need',
#  'tell',
#  'see',
#  'back',
#  'dog',
#  'baby',
#  'white',
#  'difference',
#  'always',
#  'gay',
#  'right',
#  'u',
#  '5',
#  'find',
#  'going',
#  'sex',
#  '10',
#  'friend',
#  'house',
#  'work',
#  'walk',
#  'give',
#  'bar',
#  'ever',
#  'many',
#  'come',
#  'favorite',
#  'child',
#  'mom',
#  'food',
#  'home',
#  'wife',
#  'american',
#  'someone',
#  'week',
#  'stop',
#  'change',
#  'yous',
#  'knock',
#  'men',
#  'still',
#  'last',
#  'bad',
#  'called',
#  'school',
#  'keep',
#  'little',
#  'help',
#  'name',
#  'may',
#  'today',
#  'big',
#  '2',
#  'clinton',
#  'star',
#  'watch',
#  'much',
#  'said',
#  'every',
#  'put',
#  'eat',
#  'bill',
#  'made',
#  'family',
#  'old',
#  '3',
#  'car',
#  'state',
#  'dead',
#  'police',
#  'wedding',
#  'use',
#  'game',
#  'health',
#  'night',
#  'america',
#  'better',
#  'let',
#  'part',
#  'obama',
#  'getting',
#  'job',
#  '7',
#  'even',
#  'dad',
#  'talk',
#  'hate',
#  'hillary',
#  'face',
#  'gop',
#  'great',
#  'common',
#  'long',
#  'president',
#  'study',
#  'parent',
#  'kind',
#  'girlfriend',
#  'word',
#  'top',
#  'cross',
#  'movie',
#  'q',
#  'turn',
#  'well',
#  'mean',
#  'wear',
#  'party',
#  'red',
#  'real',
#  'wrong',
#  'lost',
#  '6',
#  'death',
#  'cat',
#  'mexican',
#  'war',
#  'around',
#  '1',
#  'play',
#  'hit',
#  'chicken',
#  'tip',
#  'person',
#  'fat',
#  'run',
#  'next',
#  'without',
#  'mother',
#  'shit',
#  'heard',
#  'end',
#  'open',
#  'christmas',
#  'feel',
#  'money',
#  'doctor',
#  'found',
#  'told',
#  'hand',
#  'hard',
#  'boy',
#  'everyone',
#  'son',
#  'care',
#  'live',
#  'report',
#  'republican',
#  'making',
#  'fight',
#  'kill',
#  'went',
#  'win',
#  'reason',
#  'start',
#  'story',
#  'fall',
#  'lot',
#  'news',
#  'water',
#  'student',
#  'head',
#  'book',
#  'nothing',
#  'city',
#  'away',
#  'something',
#  'marriage',
#  'court',
#  'high',
#  'drink',
#  'used',
#  '4',
#  '8',
#  'another',
#  'york',
#  'leg',
#  'road',
#  'body',
#  'problem',
#  'worst',
#  'john',
#  'attack',
#  'idea',
#  'twitter',
#  'phone',
#  'plan',
#  'divorce',
#  'free',
#  'sleep',
#  'cancer',
#  'three',
#  'dick',
#  'cop',
#  'gun',
#  'question',
#  'million',
#  'fire',
#  'light',
#  'place',
#  'letter',
#  'cow',
#  'music',
#  'everything',
#  'actually',
#  'pay',
#  'buy',
#  'election',
#  'hot',
#  'eye',
#  'coffee',
#  'hair',
#  'thought',
#  'wall',
#  '9',
#  'morning',
#  'group',
#  'line',
#  'break',
#  'race',
#  'dress',
#  'daughter',
#  'fashion',
#  'second',
#  'business',
#  'style',
#  'left',
#  'pretty',
#  'stand',
#  'asked',
#  'fan',
#  'god',
#  'sorry',
#  'try',
#  'college',
#  'art',
#  'might',
#  'country',
#  'north',
#  'wanted',
#  'holiday',
#  'campaign',
#  'tree',
#  'ball',
#  'pizza',
#  'must',
#  'shooting',
#  'street',
#  'father',
#  'happy',
#  'drug',
#  'probably',
#  'tv',
#  'funny',
#  'step',
#  'hey',
#  'month',
#  'secret',
#  'history',
#  'type',
#  'cut',
#  'law',
#  'heart',
#  'climate',
#  'meet',
#  'trying',
#  'couple',
#  'summer',
#  'ask',
#  'coming',
#  'michael',
#  'eating',
#  'date',
#  'came',
#  'full',
#  'medium',
#  'vote',
#  'racist',
#  'read',
#  'jew',
#  'teen',
#  'travel',
#  'least',
#  'number',
#  'deal',
#  'fish',
#  'jesus',
#  'song',
#  'sure',
#  'facebook',
#  'muslim',
#  'sander',
#  'season',
#  'tweet',
#  'super',
#  'enough',
#  'teacher',
#  'killed',
#  'tax',
#  'tried',
#  'leave',
#  'rule',
#  'save',
#  'case',
#  'finally',
#  'support',
#  'shot',
#  'saw',
#  'share',
#  'internet',
#  'recipe',
#  'beer',
#  'move',
#  'died',
#  'perfect',
#  'apple',
#  'die',
#  '12',
#  'fuck',
#  'national',
#  'order',
#  'film',
#  'hitler',
#  'lady',
#  'email',
#  'set',
#  'side',
#  'inside',
#  'behind',
#  'sexual',
#  'sound',
#  'matter',
#  'le',
#  'moment',
#  'space',
#  'blind',
#  'rock',
#  'human',
#  'wish',
#  'russian',
#  'seen',
#  'short',
#  'post',
#  'democrat',
#  'player',
#  'happens',
#  'bernie',
#  'power',
#  'living',
#  'relationship',
#  'single',
#  'team',
#  'mind',
#  'office',
#  'please',
#  'weight',
#  'company',
#  'birthday',
#  'santa',
#  '20',
#  'blonde',
#  'box',
#  'fucking',
#  'french',
#  'future',
#  'sign',
#  'small',
#  'drive',
#  'green',
#  'kim',
#  'store',
#  'fly',
#  'james',
#  'horse',
#  'cold',
#  'looking',
#  'yet',
#  'become',
#  'animal',
#  'oh',
#  'already',
#  'claim',
#  'taste',
#  'young',
#  'russia',
#  'test',
#  'leader',
#  'using',
#  'ban',
#  'beauty',
#  'dream',
#  'anything',
#  'debate',
#  'hope',
#  'paul',
#  'easy',
#  'fun',
#  '2016',
#  'guide',
#  'ad',
#  'pick',
#  '2012',
#  '2013',
#  'brown',
#  'poll',
#  'bed',
#  'isi',
#  'bird',
#  'half',
#  'ice',
#  'together',
#  'running',
#  'stay',
#  'jewish',
#  'yes',
#  'pregnant',
#  'chinese',
#  'door',
#  'bank',
#  'room',
#  '100',
#  'happened',
#  'award',
#  'penis',
#  'bear',
#  'believe',
#  'prison',
#  'public',
#  'artist',
#  'senate',
#  'social',
#  'foot',
#  'gift',
#  'south',
#  'anyone',
#  'arm',
#  'married',
#  'taking',
#  'king',
#  'elephant',
#  'control',
#  'five',
#  'list',
#  'china',
#  'cool',
#  'reddit',
#  'remember',
#  'picture',
#  'age',
#  'as',
#  'cheese',
#  'minute',
#  'supreme',
#  'took',
#  'cover',
#  'four',
#  'dinner',
#  'fear',
#  'former',
#  'pirate',
#  'cry',
#  'female',
#  'voter',
#  'card',
#  'judge',
#  'lawyer',
#  'answer',
#  'weekend',
#  'dark',
#  'working',
#  'egg',
#  'hour',
#  'bring',
#  'middle',
#  'plane',
#  'beat',
#  'pant',
#  'risk',
#  'blue',
#  'brain',
#  'key',
#  'point',
#  'pound',
#  'yo',
#  '11',
#  'nice',
#  '15',
#  '50',
#  'hell',
#  'oscar',
#  'park',
#  'lead',
#  'celebrity',
#  'ring',
#  'toilet',
#  'air',
#  'halloween',
#  'restaurant',
#  'drop',
#  'hold',
#  'reveals',
#  'throw',
#  'feminist',
#  'paper',
#  'west',
#  'bee',
#  'california',
#  'guess',
#  'smell',
#  'german',
#  'officer',
#  'asian',
#  'blood',
#  'husband',
#  'victim',
#  'wonder',
#  'dating',
#  'lose',
#  'talking',
#  'visit',
#  'miss',
#  'past',
#  'thanks',
#  'giving',
#  'fox',
#  'jimmy',
#  'met',
#  'violence',
#  'friday',
#  'model',
#  'suicide',
#  'arrested',
#  'computer',
#  'since',
#  'church',
#  'beautiful',
#  'class',
#  'gave',
#  'club',
#  'shoe',
#  'suck',
#  'healthy',
#  'saying',
#  'bowl',
#  'lesson',
#  'outside',
#  'speech',
#  'chuck',
#  'crisis',
#  'whole',
#  'hotel',
#  'late',
#  'protest',
#  'return',
#  'ryan',
#  'candidate',
#  'trip',
#  'cost',
#  'front',
#  'korea',
#  'sea',
#  'wait',
#  '2014',
#  '911',
#  'afraid',
#  'issue',
#  'official',
#  'paris',
#  'true',
#  'walking',
#  'stephen',
#  'texas',
#  'huffpost',
#  'instead',
#  'biggest',
#  'dance',
#  'learned',
#  'hole',
#  'david',
#  'rape',
#  'birth',
#  'harry',
#  'close',
#  'earth',
#  'turkey',
#  'congress',
#  'learn',
#  'lesbian',
#  'rise',
#  'sister',
#  'advice',
#  'asks',
#  'milk',
#  'stupid',
#  'bathroom',
#  'driver',
#  'drunk',
#  'football',
#  'interview',
#  'major',
#  'named',
#  'pope',
#  'v',
#  'beach',
#  'finger',
#  'clean',
#  'piece',
#  'chris',
#  'playing',
#  'brother',
#  'force',
#  'killing',
#  'mama',
#  'worse',
#  'almost',
#  'government',
#  'florida',
#  'nobody',
#  'science',
#  'sometimes',
#  'started',
#  'cake',
#  'online',
#  'band',
#  'catch',
#  'crime',
#  'security',
#  'winter',
#  'fast',
#  'missing',
#  'sick',
#  'message',
#  'amazing',
#  'fell',
#  'special',
#  'wearing',
#  'fake',
#  'prince',
#  'tom',
#  'understand',
#  'sale',
#  'favourite',
#  'fit',
#  'ghost',
#  'presidential',
#  'raise',
#  'window',
#  'table',
#  'homeless',
#  'lightbulb',
#  'ok',
#  'surprise',
#  'apparently',
#  'laugh',
#  'ex',
#  'google',
#  'offer',
#  'color',
#  'diet',
#  'fired',
#  'push',
#  'sport',
#  'spring',
#  'duck',
#  'kardashian',
#  'policy',
#  'worker',
#  'math',
#  'abortion',
#  'dy',
#  'glass',
#  'instagram',
#  'record',
#  'scientist',
#  'six',
#  'pull',
#  'la',
#  'bought',
#  'dollar',
#  'mark',
#  'wine',
#  'bush',
#  'challenge',
#  'done',
#  'murder',
#  'accused',
#  'aid',
#  'far',
#  'gas',
#  'obamacare',
#  'charge',
#  'justice',
#  'political',
#  'refugee',
#  'rose',
#  'act',
#  'poor',
#  'battle',
#  'teach',
#  'town',
#  'wood',
#  'community',
#  'join',
#  'lie',
#  'mistake',
#  'porn',
#  'shop',
#  'terrible',
#  'maybe',
#  'release',
#  'snl',
#  'blow',
#  'count',
#  'disease',
#  'early',
#  'gold',
#  'kate',
#  'march',
#  'straight',
#  'trailer',
#  'according',
#  'comment',
#  'george',
#  'mike',
#  'obamas',
#  'steve',
#  'pig',
#  'ate',
#  'jenner',
#  'loss',
#  'patient',
#  'series',
#  'snow',
#  'vegetable',
#  'born',
#  'lgbt',
#  'tired',
#  'military',
#  'washington',
#  'forget',
#  'huge',
#  'important',
#  'sandwich',
#  'worth',
#  '13',
#  'director',
#  'simple',
#  'weird',
#  'christian',
#  'hill',
#  'taylor',
#  'burn',
#  'crazy',
#  'nut',
#  'hipster',
#  'norris',
#  'powerful',
#  'avoid',
#  'reportedly',
#  'bag',
#  'cannibal',
#  'chocolate',
#  'crash',
#  'queen',
#  'stuck',
#  'changed',
#  'damn',
#  'italian',
#  'male',
#  'drinking',
#  'field',
#  'honor',
#  'leaf',
#  'period',
#  'hollywood',
#  'iran',
#  'valentine',
#  'yesterday',
#  '30',
#  'assault',
#  'different',
#  'ted',
#  'check',
#  'hospital',
#  'potato',
#  'service',
#  'wake',
#  'adorable',
#  'also',
#  'calling',
#  'caught',
#  'fighting',
#  'justin',
#  'meeting',
#  'midget',
#  'nazi',
#  'st',
#  'thank',
#  'train',
#  'trust',
#  'watching',
#  '2015',
#  'colbert',
#  'fact',
#  'ready',
#  'turned',
#  'driving',
#  'land',
#  'role',
#  'roll',
#  'credit',
#  'latest',
#  'meat',
#  'across',
#  'cup',
#  'rest',
#  'ride',
#  '14',
#  'batman',
#  'chief',
#  'note',
#  'orange',
#  'pet',
#  'senator',
#  'ear',
#  'flight',
#  'hurt',
#  'iphone',
#  'thinking',
#  'fruit',
#  'trick',
#  'else',
#  'olympics',
#  'thanksgiving',
#  'breakfast',
#  'priest',
#  'sad',
#  'sell',
#  'shower',
#  'telling',
#  'nfl',
#  'scott',
#  'shoot',
#  'toddler',
#  'update',
#  'airline',
#  'clothes',
#  'final',
#  'frog',
#  'third',
#  'worry',
#  'chair',
#  'cruz',
#  'finding',
#  'mouth',
#  'nose',
#  'boyfriend',
#  'bus',
#  'condom',
#  'disney',
#  'screw',
#  'ugly',
#  'vacation',
#  'awesome',
#  'cream',
#  'pedophile',
#  'princess',
#  'response',
#  'stress',
#  'system',
#  'us',
#  'education',
#  'feeling',
#  'kick',
#  'queer',
#  'stick',
#  'course',
#  'idiot',
#  'later',
#  'planet',
#  'butt',
#  'member',
#  'mental',
#  'slam',
#  'totally',
#  'trans',
#  'celebrate',
#  'democratic',
#  'indian',
#  'knew',
#  'reality',
#  '25',
#  'add',
#  'bet',
#  'british',
#  'global',
#  'actor',
#  'tie',
#  'yoga',
#  'character',
#  'london',
#  'skin',
#  'broke',
#  'dear',
#  'jail',
#  'longer',
#  'thousand',
#  'banana',
#  'bit',
#  'dinosaur',
#  'exercise',
#  'popular',
#  'choice',
#  'expert',
#  'ground',
#  'pilot',
#  'supporter',
#  'building',
#  'ceo',
#  'golden',
#  'safe',
#  'vampire',
#  'bread',
#  'clock',
#  'farmer',
#  'fix',
#  'jennifer',
#  'lawmaker',
#  'reading',
#  'smith',
#  'twin',
#  'welcome',
#  'bomb',
#  'large',
#  'meal',
#  'mine',
#  'nail',
#  'transgender',
#  'ben',
#  'double',
#  'event',
#  'machine',
#  'makeup',
#  'michelle',
#  'action',
#  'flying',
#  'olympic',
#  'prostitute',
#  'smart',
#  'spot',
#  'success',
#  'swift',
#  'blame',
#  ...]

# %%
# get indices of unknown index andpad index
unk_index = vocab["<unk>"]
pad_index = vocab["<pad>"]

# %%
vocab.set_default_index(unk_index) # so that if some words are not in the vocabulary, we will use <unk> instead of that unknown word

# %% [markdown]
# Numericalizing the text data

# %%
def numericalize(sent, vocab):
    ids = vocab.lookup_indices(sent["tokens"]) # The lookup_indices() method looks up a list of tokens in our vocabulary
    return {"ids": ids}

# %%
X_train = [numericalize(x, vocab) for x in X_train]

# %%
X_train
# Out:
# [{'ids': [25, 6, 1785, 5, 375]},
#  {'ids': [363, 61, 197, 28, 192, 174]},
#  {'ids': [16, 4957, 0, 3554, 1629, 9752, 209, 1722]},
#  {'ids': [3192, 0, 55, 1383, 528, 6377, 679, 2949]},
#  {'ids': [102, 33, 5, 2627, 1840, 4127]},
#  {'ids': [678, 2249, 5054, 416, 1824, 35, 23, 0]},
#  {'ids': [43, 1532, 38, 28, 1367, 2158, 151]},
#  {'ids': [1041, 433, 3227, 281, 2067, 376, 826, 350]},
#  {'ids': [579, 104, 1496, 46, 3453]},
#  {'ids': [3, 171, 506, 8598, 7350]},
#  {'ids': [825, 412, 33, 1907, 801]},
#  {'ids': [0, 2, 154, 8031]},
#  {'ids': [45, 378, 270, 52, 153, 0]},
#  {'ids': [986, 7581, 13, 535, 589, 1167]},
#  {'ids': [812, 5955, 95, 2017, 10113]},
#  {'ids': [765, 5669, 7537, 647, 31, 368, 848, 29, 368, 2082]},
#  {'ids': [238, 27, 1998, 205, 12488, 3339, 0]},
#  {'ids': [766, 6585, 4534, 2350, 0, 8522, 6574, 5486, 10209]},
#  {'ids': [8615, 1470, 203, 3773, 260]},
#  {'ids': [14212, 87, 11705, 572, 649, 0, 469, 10242, 268, 10514]},
#  {'ids': [1124, 3642, 84, 2482, 10141, 2371, 8322]},
#  {'ids': [3884, 4297, 412, 8306, 836, 310, 83, 1040, 3345]},
#  {'ids': [123, 0, 2776, 27, 12, 12047]},
#  {'ids': [0, 1997, 121, 192, 1147, 3873, 124, 39, 21]},
#  {'ids': [134, 100, 5598, 4945, 260, 294, 2624, 6973, 610]},
#  {'ids': [0, 1810, 2082, 5, 1287, 162, 1037]},
#  {'ids': [150, 4999, 2497, 9528, 3437, 478, 5829, 927]},
#  {'ids': [1821, 0, 1452, 203, 0]},
#  {'ids': [34, 181, 324, 312, 60, 2000, 162, 544]},
#  {'ids': [244, 77, 6, 199, 2001, 978, 1536, 2366]},
#  {'ids': [185, 2614, 9, 10144, 104, 152]},
#  {'ids': [4354, 812, 95, 2791, 4642, 3, 2626, 4074]},
#  {'ids': [250, 238, 24, 111, 4, 2, 2581, 794, 4201, 2128, 8425, 437]},
#  {'ids': [14, 1809, 581, 1390, 6783, 2684, 412]},
#  {'ids': [3280, 1739, 6386, 3911, 8852, 1294, 3043]},
#  {'ids': [1481, 331, 11605, 390, 1731]},
#  {'ids': [8, 140, 422, 3965, 909, 1364, 0, 2, 58]},
#  {'ids': [210, 8780, 1048, 195, 256, 2284, 38, 172, 2804, 0]},
#  {'ids': [0, 5691, 4, 0, 2879, 40, 2, 30, 14830]},
#  {'ids': [31, 1193, 637, 131, 70, 584, 58]},
#  {'ids': [1929, 78, 1367, 179, 466, 693, 1279, 46, 2454]},
#  {'ids': [552, 10754, 5276, 2457, 577, 3278]},
#  {'ids': [45, 2915, 4051, 170]},
#  {'ids': [1146, 792, 9429, 2802, 103, 660, 100, 371, 2047]},
#  {'ids': [2800, 3750, 487, 92, 5216, 5216]},
#  {'ids': [2290, 1028, 77, 1737, 3468, 0, 0, 8]},
#  {'ids': [857, 510, 30, 1776, 34, 3270, 2155, 1704, 379, 78]},
#  ...]

# %% [markdown]
# Padding each sentence with our default padding value

# %%
X_train = [torch.as_tensor(x['ids']) for x in X_train]
X_train = torch.nn.utils.rnn.pad_sequence(X_train, batch_first=True, padding_value=pad_index)

# %%
X_train
# Out:
# tensor([[  25,    6, 1785,  ...,    1,    1,    1],
#         [ 363,   61,  197,  ...,    1,    1,    1],
#         [  16, 4957,    0,  ...,    1,    1,    1],
#         ...,
#         [   0,    0,  104,  ...,    1,    1,    1],
#         [ 302,   35, 1969,  ...,    1,    1,    1],
#         [1279,  968, 3334,  ...,    1,    1,    1]])

# %%
X_valid = [torch.as_tensor(x['ids']) for x in X_valid]
X_valid = torch.nn.utils.rnn.pad_sequence(X_valid, batch_first=True, padding_value=pad_index)

# %%
X_valid
# Out:
# tensor([[ 9854,    76,  1182,  ...,     1,     1,     1],
#         [   56,    64,   292,  ...,     1,     1,     1],
#         [ 8397,  9433,   976,  ...,     1,     1,     1],
#         ...,
#         [  392,  1479,    42,  ...,     1,     1,     1],
#         [ 1196,  5128,   880,  ...,     1,     1,     1],
#         [ 9668, 13791,  1060,  ...,     1,     1,     1]])

# %%
X_test = [torch.as_tensor(x['ids']) for x in X_test]
X_test = torch.nn.utils.rnn.pad_sequence(X_test, batch_first=True, padding_value=pad_index)

# %%
X_test
# Out:
# tensor([[ 259,  492,   20,  ...,    1,    1,    1],
#         [ 103,  506,  252,  ...,    1,    1,    1],
#         [ 134,  100, 1674,  ...,    1,    1,    1],
#         ...,
#         [  31,  297,   62,  ...,    1,    1,    1],
#         [ 689, 1595, 2713,  ...,    1,    1,    1],
#         [1637,    0,  310,  ...,    1,    1,    1]])

# %% [markdown]
# Convert the target values from numpy arrays into tensors

# %%
y_train = torch.as_tensor(train_targets_np.astype(float))
y_train
# Out:
# tensor([0., 1., 0.,  ..., 0., 1., 1.], dtype=torch.float64)

# %%
y_valid = torch.as_tensor(valid_targets_np.astype(float))
y_valid
# Out:
# tensor([0., 1., 0.,  ..., 0., 1., 0.], dtype=torch.float64)

# %%
y_test = torch.as_tensor(test_targets_np.astype(float))
y_test
# Out:
# tensor([1., 1., 0.,  ..., 1., 0., 0.], dtype=torch.float64)

# %% [markdown]
# # Using TensorDataset and DataLoader on our data

# %%
train = TensorDataset(X_train, y_train)
valid = TensorDataset(X_valid, y_valid)
test = TensorDataset(X_test, y_test)

# %%
BATCH_SIZE = 512

# %%
train_loader = DataLoader(train, batch_size = BATCH_SIZE , shuffle = True)
valid_loader = DataLoader(valid, batch_size = BATCH_SIZE, shuffle = True)
test_loader = DataLoader(test, batch_size = BATCH_SIZE, shuffle = True)

# %% [markdown]
# # Creating the RNN model

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, n_layers, dropout):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.n_layers = n_layers
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.rnn = nn.RNN(hidden_size, hidden_size, n_layers, batch_first=True, dropout=dropout if n_layers > 1 else 0)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, x, hidden):
        embedded = self.embedding(x)
        output, hidden = self.rnn(embedded, hidden)
        output = self.dropout(output)  # Apply dropout after the RNN layers
        output = self.fc(output[:, -1, :])
        output = self.softmax(output)
        return output, hidden

    def init_hidden(self, batch_size):
        return torch.zeros(self.n_layers, batch_size, self.hidden_size).to(next(self.parameters()).device) # hidden state is a tensor that stores information from previous time steps and is used to influence the current output.

# %% [markdown]
# # Training of the RNN model
#
# https://github.com/keishinkickback/Pytorch-RNN-text-classification

# %%
vocab_size = len(vocab)
embedding_dim = 300
hidden_dim = 300
output_dim = 2 # binary classification
n_layers = 2
dropout = 0.5
# bidirectional = False
# dropout_rate = 0.5

model = RNN(
    vocab_size,
    hidden_dim,
    output_dim,
    n_layers,
    dropout
)

# %%
# number of trainable parameters for the LSTM network
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


print(f"The model has {count_parameters(model):,} trainable parameters")
# Out:
# The model has 4,959,302 trainable parameters

# %%
# function to initialize weight of the LSTM network
def initialize_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_normal_(m.weight)
        nn.init.zeros_(m.bias)
    elif isinstance(m, nn.RNN):
        for name, param in m.named_parameters():
            if "bias" in name:
                nn.init.zeros_(param)
            elif "weight" in name:
                nn.init.orthogonal_(param)

# %%
model.apply(initialize_weights)
# Out:
# RNN(
#   (embedding): Embedding(15325, 300)
#   (rnn): RNN(300, 300, num_layers=2, batch_first=True, dropout=0.5)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=300, out_features=2, bias=True)
#   (softmax): LogSoftmax(dim=1)
# )

# %%
vectors = torchtext.vocab.GloVe()
# Out:
# .vector_cache/glove.840B.300d.zip: 2.18GB [06:50, 5.31MB/s]
# 100%|█████████▉| 2196016/2196017 [04:56<00:00, 7406.98it/s]

# %%
pretrained_embedding = vectors.get_vecs_by_tokens(vocab.get_itos())

# %%
model.embedding.weight.data = pretrained_embedding

# %%
lr = 5e-4

optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
criterion = nn.CrossEntropyLoss()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

device
# Out:
# device(type='cuda')

# %%
model = model.to(device)
criterion = criterion.to(device)

# %%
epochs = 10
train_acc = []
val_acc = []
train_loss_lst = []
val_loss_lst = []
best_valid_loss = float("inf")

for epoch in range(epochs):
    model.train()
    epoch_train_loss = 0
    epoch_train_correct = 0
    epoch_train_total = 0
    hidden = model.init_hidden(BATCH_SIZE).to(device)  # Initialize hidden state at the start of each epoch

    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        targets = targets.view(-1).type(torch.LongTensor).to(device)
        batch_size = inputs.size(0) # Get the current batch size

        hidden = model.init_hidden(batch_size).to(device)  # Initialize hidden state for the current batch

        optimizer.zero_grad()
        output, hidden = model(inputs.to(device), hidden.to(device))  # Pass the hidden state to the RNN

        hidden = hidden.detach()
        train_loss = criterion(output, targets.to(device))
        train_loss.backward()
        optimizer.step()

        epoch_train_loss += train_loss.item()

        # Calculate training accuracy
        _, predicted = torch.max(output.data, 1)
        epoch_train_total += targets.size(0)
        epoch_train_correct += (predicted == targets).sum().item()
    average_train_loss = epoch_train_loss / len(train_loader)
    train_accuracy = epoch_train_correct / epoch_train_total

    train_loss_lst.append(average_train_loss)
    train_acc.append(train_accuracy)

    model.eval()
    epoch_val_loss = 0
    epoch_val_correct = 0
    epoch_val_total = 0
    with torch.no_grad():
        for inputs, targets in valid_loader:
          inputs, targets = inputs.to(device), targets.to(device)
          targets = targets.view(-1).type(torch.LongTensor).to(device)

          batch_size = inputs.size(0)
          hidden = model.init_hidden(batch_size).to(device)

          output, hidden = model(inputs, hidden)
          val_loss = criterion(output, targets)

          epoch_val_loss += val_loss.item()

          # Calculate validation accuracy
          _, predicted = torch.max(output.data, 1)
          epoch_val_total += targets.size(0)
          epoch_val_correct += (predicted == targets).sum().item()

    average_val_loss = epoch_val_loss / len(valid_loader)
    val_accuracy = epoch_val_correct / epoch_val_total

    if average_val_loss < best_valid_loss:
        best_valid_loss = average_val_loss
        torch.save(model.state_dict(), "rnn.pt")

    val_loss_lst.append(average_val_loss)
    val_acc.append(val_accuracy)
    print(f'Epoch {epoch+1}, Training Loss: {train_loss.item(): .4f}, Training Accuracy: {train_accuracy:.4f},  Validation Loss: {val_loss.item(): .4f}, Validation Accuracy: {val_accuracy:.4f}')
# Out:
# Epoch 1, Training Loss:  0.2642, Training Accuracy: 0.8566,  Validation Loss:  0.2026, Validation Accuracy: 0.8981
# Epoch 2, Training Loss:  0.2876, Training Accuracy: 0.9071,  Validation Loss:  0.1559, Validation Accuracy: 0.9072
# Epoch 3, Training Loss:  0.1972, Training Accuracy: 0.9254,  Validation Loss:  0.1784, Validation Accuracy: 0.9078
# Epoch 4, Training Loss:  0.2092, Training Accuracy: 0.9377,  Validation Loss:  0.1513, Validation Accuracy: 0.9103
# Epoch 5, Training Loss:  0.1552, Training Accuracy: 0.9470,  Validation Loss:  0.2198, Validation Accuracy: 0.9064
# Epoch 6, Training Loss:  0.1338, Training Accuracy: 0.9565,  Validation Loss:  0.3842, Validation Accuracy: 0.9077
# Epoch 7, Training Loss:  0.1208, Training Accuracy: 0.9656,  Validation Loss:  0.3432, Validation Accuracy: 0.9055
# Epoch 8, Training Loss:  0.0775, Training Accuracy: 0.9732,  Validation Loss:  0.2349, Validation Accuracy: 0.9039
# Epoch 9, Training Loss:  0.0981, Training Accuracy: 0.9787,  Validation Loss:  0.4551, Validation Accuracy: 0.9009
# Epoch 10, Training Loss:  0.0461, Training Accuracy: 0.9834,  Validation Loss:  0.4870, Validation Accuracy: 0.9042

# %%
print(f'Train accuracy list: {train_acc}')
print(f'Validation accuracy list: {val_acc}')
print(f'Train loss list: {train_loss_lst}')
print(f'Validation loss list: {val_loss_lst}')
# Out:
# Train accuracy list: [0.8565555555555555, 0.9070555555555555, 0.9253680555555556, 0.9376597222222223, 0.9470416666666667, 0.9565277777777778, 0.9655972222222222, 0.9731597222222222, 0.9787222222222223, 0.9834444444444445]
# Validation accuracy list: [0.898125, 0.9071875, 0.9078125, 0.91025, 0.9064375, 0.90775, 0.9055, 0.903875, 0.900875, 0.9041875]
# Train loss list: [0.3459231836047578, 0.23232037077347437, 0.1902280126744551, 0.16142988804701372, 0.13795469854529022, 0.11525070746528342, 0.09466824794174931, 0.07471662593331743, 0.060023013892061744, 0.0482190105311097]
# Validation loss list: [0.2721491330303252, 0.22993171541020274, 0.23763687629252672, 0.24168470269069076, 0.2517215861007571, 0.276856224052608, 0.3170834886841476, 0.3100499454885721, 0.3609720431268215, 0.4033748498186469]

# %% [markdown]
# Plot training and testing loss

# %%
plt.figure(figsize=(10, 6))

plt.plot(train_loss_lst)
plt.plot(val_loss_lst)

plt.xlabel("Number of epochs")
plt.ylabel("Loss value")
plt.title("Loss against number of epochs")

plt.legend(['train loss', 'validation loss'])

plt.show()

# %% [markdown]
# Plot training and testing accuracy

# %%
plt.figure(figsize=(10, 6))

plt.plot(train_acc)
plt.plot(val_acc)

plt.xlabel("Number of epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy against number of epochs")

plt.legend(['train accuracy', 'validation accuracy'])

plt.show()

# %% [markdown]
# # Trying the model on test data

# %%
vocab_size = len(vocab)
embedding_dim = 300
hidden_dim = 300
output_dim = 2 # binary classification
n_layers = 2
dropout = 0.5

best_model = RNN(
    vocab_size,
    hidden_dim,
    output_dim,
    n_layers,
    dropout
)

best_model.load_state_dict(torch.load('rnn.pt'))
best_model.to(device)
best_model.eval()
test_loss = 0
test_correct = 0
test_total = 0

with torch.no_grad():
    for inputs, targets in test_loader:
        inputs, targets = inputs.to(device), targets.view(-1).type(torch.LongTensor).to(device)

        batch_size = inputs.size(0)
        hidden = best_model.init_hidden(batch_size).to(device)

        output, hidden = best_model(inputs, hidden)
        loss = criterion(output, targets)

        test_loss += loss.item()

        # Calculate test accuracy
        _, predicted = torch.max(output.data, 1)
        test_total += targets.size(0)
        test_correct += (predicted == targets).sum().item()

average_test_loss = test_loss / len(test_loader)
test_accuracy = test_correct / test_total

print(f'Test Loss: {average_test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}')
# Out:
# Test Loss: 0.2447, Test Accuracy: 0.9005
